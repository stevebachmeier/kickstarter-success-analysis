# %%
# ========================================
# IMPORT LIBRARIES
# ========================================
import pandas as pd
import numpy as np
import json
import dill 
from IPython.display import display

# %%
# ========================================
# LOAD/SAVE SESSIONS
# ========================================
#filename = 'notebook_env_analysis.db'
#dill.dump_session(filename)

# and to load the session again:
#dill.load_session(filename)

# %%
# ========================================
# READ/EXTRACT RELEVANT DATA
# ========================================
with open("data/Kickstarter_2018-10-18T03_20_48_880Z.json/Kickstarter_2018-10-18T03_20_48_880Z.json",
          encoding="utf8") as json_file:
    json_obj = [json.loads(line) for line in json_file]

# %%
# ---- Quick exploration ----

# %%
type(json_obj)
# Out:
# list

# %%
len(json_obj)
# Out:
# 205696

# %%
type(json_obj[0])
# Out:
# dict

# %%
len(json_obj[0])
# Out:
# 4

# %%
json_obj[len(json_obj)-1] # look at final entry
# Out:
# {'table_id': 'Kickstarter',
#  'robot_id': 'Kickstarter',
#  'run_id': 'Kickstarter_2018-10-18T03_20_48_880Z',
#  'data': {'id': 1991284368,
#   'photo': {'key': 'assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png',
#    'full': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=560&h=315&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=02368a096ce01fc6cae29ab85df52d53',
#    'ed': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=352&h=198&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=7c87714e96670269be821591da0ddbb1',
#    'med': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=272&h=153&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=7ce6128059b609c7603ab19d113e7c55',
#    'little': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=208&h=117&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=04ea8b7b8a8eb7da2cda7e77c44eab8e',
#    'small': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=160&h=90&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=cb7054d89e3115543343be1d167ccc80',
#    'thumb': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=48&h=27&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=b56e49b8d16b5b9d63de0a0fc7c78ee0',
#    '1024x576': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=1024&h=576&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=766fc63209f2030f8adb9ef1010dbbd8',
#    '1536x864': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=1552&h=873&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=bc19bfa1b4335b14d9119ef9ba5f0591'},
#   'name': 'Get Hula Cowgirl Shaved Ice Over the Last Bump!',
#   'blurb': 'We are opening what we hope will be a wonderful shaved ice experience for the residents of and visitors to Georgetown, Texas!',
#   'goal': 3000,
#   'pledged': 35,
#   'state': 'failed',
#   'slug': 'get-hula-cowgirl-shaved-ice-over-the-last-bump',
#   'disable_communication': False,
#   'country': 'US',
#   'currency': 'USD',
#   'currency_symbol': '$',
#   'currency_trailing_code': True,
#   'deadline': 1408057020,
#   'state_changed_at': 1408057020,
#   'created_at': 1405914894,
#   'launched_at': 1406739106,
#   'staff_pick': False,
#   'is_starrable': False,
#   'backers_count': 3,
#   'static_usd_rate': 1,
#   'usd_pledged': '35.0',
#   'converted_pledged_amount': 35,
#   'fx_rate': 1,
#   'current_currency': 'USD',
#   'usd_type': 'international',
#   'creator': {'id': 923311576,
#    'name': 'Virginia Keeley',
#    'is_registered': True,
#    'chosen_currency': None,
#    'avatar': {'thumb': 'https://ksr-ugc.imgix.net/assets/009/082/074/38f1f75e252ef1a1618f5a8f1b553816_original.jpg?ixlib=rb-1.1.0&w=40&h=40&fit=crop&v=1461556778&auto=format&frame=1&q=92&s=3e2a419f117c09a1616c245bba3391cc',
#     'small': 'https://ksr-ugc.imgix.net/assets/009/082/074/38f1f75e252ef1a1618f5a8f1b553816_original.jpg?ixlib=rb-1.1.0&w=160&h=160&fit=crop&v=1461556778&auto=format&frame=1&q=92&s=178011af1e24a9fa714fea5902fcd0cd',
#     'medium': 'https://ksr-ugc.imgix.net/assets/009/082/074/38f1f75e252ef1a1618f5a8f1b553816_original.jpg?ixlib=rb-1.1.0&w=160&h=160&fit=crop&v=1461556778&auto=format&frame=1&q=92&s=178011af1e24a9fa714fea5902fcd0cd'},
#    'urls': {'web': {'user': 'https://www.kickstarter.com/profile/923311576'},
#     'api': {'user': 'https://api.kickstarter.com/v1/users/923311576?signature=1539925746.73341825197dafd9c6241dd19a4bcc1b9b77f449'}}},
#   'location': {'id': 2409678,
#    'name': 'Georgetown',
#    'slug': 'georgetown-tx',
#    'short_name': 'Georgetown, TX',
#    'displayable_name': 'Georgetown, TX',
#    'localized_name': 'Georgetown',
#    'country': 'US',
#    'state': 'TX',
#    'type': 'Town',
#    'is_root': False,
#    'urls': {'web': {'discover': 'https://www.kickstarter.com/discover/places/georgetown-tx',
#      'location': 'https://www.kickstarter.com/locations/georgetown-tx'},
#     'api': {'nearby_projects': 'https://api.kickstarter.com/v1/discover?signature=1539904425.aa4d5a1dc3262bf79c2d1691682064f3a8be1686&woe_id=2409678'}}},
#   'category': {'id': 312,
#    'name': 'Restaurants',
#    'slug': 'food/restaurants',
#    'position': 9,
#    'parent_id': 10,
#    'color': 16725570,
#    'urls': {'web': {'discover': 'http://www.kickstarter.com/discover/categories/food/restaurants'}}},
#   'profile': {'id': 1208668,
#    'project_id': 1208668,
#    'state': 'inactive',
#    'state_changed_at': 1425915867,
#    'name': None,
#    'blurb': None,
#    'background_color': None,
#    'text_color': None,
#    'link_background_color': None,
#    'link_text_color': None,
#    'link_text': None,
#    'link_url': None,
#    'show_feature_image': False,
#    'background_image_opacity': 0.8,
#    'should_show_feature_image_section': True,
#    'feature_image_attributes': {'image_urls': {'default': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=1552&h=873&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=bc19bfa1b4335b14d9119ef9ba5f0591',
#      'baseball_card': 'https://ksr-ugc.imgix.net/assets/011/796/998/9d7e9715ca5b8227f29de01f3c4abc8f_original.png?ixlib=rb-1.1.0&crop=faces&w=560&h=315&fit=crop&v=1463696010&auto=format&frame=1&q=92&s=02368a096ce01fc6cae29ab85df52d53'}}},
#   'spotlight': False,
#   'urls': {'web': {'project': 'https://www.kickstarter.com/projects/923311576/get-hula-cowgirl-shaved-ice-over-the-last-bump?ref=category_newest',
#     'rewards': 'https://www.kickstarter.com/projects/923311576/get-hula-cowgirl-shaved-ice-over-the-last-bump/rewards'}},
#   'source_url': 'https://www.kickstarter.com/discover/categories/food/restaurants'}}

# %%
json_obj[0].keys()
# Out:
# dict_keys(['table_id', 'robot_id', 'run_id', 'data'])

# %%
# The useful keys are 'data'

# %%
# Extract relevant data
# pre-allocate
json_obj2 = []
# append 'data' dictionary only
for x in range(0, len(json_obj)):
    json_obj2.append(json_obj[x]["data"])

# %%
len(json_obj2) - len(json_obj) # Check that all rows extracted
# Out:
# 0

# %%
json_obj2[0]
# Out:
# {'id': 895922629,
#  'photo': {'key': 'assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg',
#   'full': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=560&h=315&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=846b5db7dd4a36491881770969721fab',
#   'ed': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=352&h=198&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=c2d76a75d1cd815488d3d3b651b49222',
#   'med': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=272&h=153&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=f938afb8f27ea25f81b3f57bc8349d88',
#   'little': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=208&h=117&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=69632b0cf7a30977d7eb58a05f3bd315',
#   'small': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=160&h=90&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=348d4ae4d6510c9b470edb3e3e820f73',
#   'thumb': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=48&h=27&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=e9616d563b12303f8fea361ef31478b2',
#   '1024x576': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=1024&h=576&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=fb504f53f9713cded89f1264d5f1c6ef',
#   '1536x864': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=1552&h=873&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=f57666c5f7328d47e63f8b389a84bfef'},
#  'name': 'Jozii-College Jobs Made Easy',
#  'blurb': 'Jozii is the premier service for full-time university students to find paid part-time work and internships.',
#  'goal': 3500,
#  'pledged': 50,
#  'state': 'failed',
#  'slug': 'jozii-college-jobs-made-easy',
#  'disable_communication': False,
#  'country': 'US',
#  'currency': 'USD',
#  'currency_symbol': '$',
#  'currency_trailing_code': True,
#  'deadline': 1417150740,
#  'state_changed_at': 1417150742,
#  'created_at': 1413476386,
#  'launched_at': 1414525374,
#  'staff_pick': False,
#  'is_starrable': False,
#  'backers_count': 1,
#  'static_usd_rate': 1,
#  'usd_pledged': '50.0',
#  'converted_pledged_amount': 50,
#  'fx_rate': 1,
#  'current_currency': 'USD',
#  'usd_type': 'international',
#  'creator': {'id': 69089661,
#   'name': 'AJ Smith and Brandon Maier (deleted)',
#   'slug': 'joziijobs',
#   'is_registered': True,
#   'chosen_currency': None,
#   'avatar': {'thumb': 'https://ksr-ugc.imgix.net/missing_user_avatar.png?ixlib=rb-1.1.0&w=40&h=40&fit=crop&v=&auto=format&frame=1&q=92&s=c8baefb239621e7b5b26957577e078db',
#    'small': 'https://ksr-ugc.imgix.net/missing_user_avatar.png?ixlib=rb-1.1.0&w=160&h=160&fit=crop&v=&auto=format&frame=1&q=92&s=fea4448b425bb704dead957d7448b9cc',
#    'medium': 'https://ksr-ugc.imgix.net/missing_user_avatar.png?ixlib=rb-1.1.0&w=160&h=160&fit=crop&v=&auto=format&frame=1&q=92&s=fea4448b425bb704dead957d7448b9cc'},
#   'urls': {'web': {'user': 'https://www.kickstarter.com/profile/joziijobs'},
#    'api': {'user': 'https://api.kickstarter.com/v1/users/69089661?signature=1539920420.2da0e34dfcb087a277252ace8e292e04f47e953d'}}},
#  'location': {'id': 12589342,
#   'name': 'Manhattan',
#   'slug': 'manhattan-ny',
#   'short_name': 'Manhattan, NY',
#   'displayable_name': 'Manhattan, NY',
#   'localized_name': 'Manhattan',
#   'country': 'US',
#   'state': 'NY',
#   'type': 'County',
#   'is_root': False,
#   'urls': {'web': {'discover': 'https://www.kickstarter.com/discover/places/manhattan-ny',
#     'location': 'https://www.kickstarter.com/locations/manhattan-ny'},
#    'api': {'nearby_projects': 'https://api.kickstarter.com/v1/discover?signature=1539904398.aae3553d1e62a16aac55da44ac8c71966f64bb86&woe_id=12589342'}}},
#  'category': {'id': 342,
#   'name': 'Web',
#   'slug': 'technology/web',
#   'position': 15,
#   'parent_id': 16,
#   'color': 6526716,
#   'urls': {'web': {'discover': 'http://www.kickstarter.com/discover/categories/technology/web'}}},
#  'profile': {'id': 1445394,
#   'project_id': 1445394,
#   'state': 'inactive',
#   'state_changed_at': 1425915879,
#   'name': None,
#   'blurb': None,
#   'background_color': None,
#   'text_color': None,
#   'link_background_color': None,
#   'link_text_color': None,
#   'link_text': None,
#   'link_url': None,
#   'show_feature_image': False,
#   'background_image_opacity': 0.8,
#   'should_show_feature_image_section': True,
#   'feature_image_attributes': {'image_urls': {'default': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=1552&h=873&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=f57666c5f7328d47e63f8b389a84bfef',
#     'baseball_card': 'https://ksr-ugc.imgix.net/assets/011/911/160/2ff8292ff8ad7486f38ea865a9c030bb_original.jpg?ixlib=rb-1.1.0&crop=faces&w=560&h=315&fit=crop&v=1463713991&auto=format&frame=1&q=92&s=846b5db7dd4a36491881770969721fab'}}},
#  'spotlight': False,
#  'urls': {'web': {'project': 'https://www.kickstarter.com/projects/joziijobs/jozii-college-jobs-made-easy?ref=category_newest',
#    'rewards': 'https://www.kickstarter.com/projects/joziijobs/jozii-college-jobs-made-easy/rewards'}},
#  'source_url': 'https://www.kickstarter.com/discover/categories/technology/web'}

# %%
# ---- EXTRACT RELEVANT COLUMNS ----
json_obj2[0].keys()
# Out:
# dict_keys(['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug', 'disable_communication', 'country', 'currency', 'currency_symbol', 'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at', 'launched_at', 'staff_pick', 'is_starrable', 'backers_count', 'static_usd_rate', 'usd_pledged', 'converted_pledged_amount', 'fx_rate', 'current_currency', 'usd_type', 'creator', 'location', 'category', 'profile', 'spotlight', 'urls', 'source_url'])

# %%
# Remove probably useless keys as well as and nested-dictionary keys (to be added back later if desired): 
#   - Useless: photo, slug, urls, source_url
#   - Nested: creator, location, category, profile (to maybe be added later)
keys=('id', 'name', 'blurb', 'goal', 'pledged', 'state', 'disable_communication', 'country', 'currency', 'currency_symbol',
      'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at', 'launched_at', 'staff_pick', 'is_starrable',
      'backers_count', 'static_usd_rate', 'usd_pledged', 'converted_pledged_amount', 'fx_rate', 'current_currency', 'usd_type',
      'spotlight')

# pre-allocate
json_obj3 = []
# Append
for x in range(0, len(json_obj2)):
    json_obj3.append({k:json_obj2[x][k] for k in keys})

# %%
# ==== ADD BACK USEFUL SUB-DICTIONARY VALUES ====
# Previously removed: 'creator', 'location', 'category', 'profile'

# %%
# ---- Explore 'creator' ----

# %%
# Grab useful previously removed sub key-value pairs:
json_obj2[0]["creator"].keys()
# Out:
# dict_keys(['id', 'name', 'slug', 'is_registered', 'chosen_currency', 'avatar', 'urls'])

# %%
json_obj2[0]["creator"]
# Out:
# {'id': 69089661,
#  'name': 'AJ Smith and Brandon Maier (deleted)',
#  'slug': 'joziijobs',
#  'is_registered': True,
#  'chosen_currency': None,
#  'avatar': {'thumb': 'https://ksr-ugc.imgix.net/missing_user_avatar.png?ixlib=rb-1.1.0&w=40&h=40&fit=crop&v=&auto=format&frame=1&q=92&s=c8baefb239621e7b5b26957577e078db',
#   'small': 'https://ksr-ugc.imgix.net/missing_user_avatar.png?ixlib=rb-1.1.0&w=160&h=160&fit=crop&v=&auto=format&frame=1&q=92&s=fea4448b425bb704dead957d7448b9cc',
#   'medium': 'https://ksr-ugc.imgix.net/missing_user_avatar.png?ixlib=rb-1.1.0&w=160&h=160&fit=crop&v=&auto=format&frame=1&q=92&s=fea4448b425bb704dead957d7448b9cc'},
#  'urls': {'web': {'user': 'https://www.kickstarter.com/profile/joziijobs'},
#   'api': {'user': 'https://api.kickstarter.com/v1/users/69089661?signature=1539920420.2da0e34dfcb087a277252ace8e292e04f47e953d'}}}

# %%
# Useful keys are: 'is_registered'

# %%
# Add 'is_registered' to json_obj3
for x in range(0, len(json_obj3)):
    json_obj3[x]["creator_registered"] = json_obj2[x]["creator"]["is_registered"]

# %%
# ---- Explore 'location' ----

# %%
json_obj2[0]["location"].keys()
# Out:
# dict_keys(['id', 'name', 'slug', 'short_name', 'displayable_name', 'localized_name', 'country', 'state', 'type', 'is_root', 'urls'])

# %%
json_obj2[0]["location"]
# Out:
# {'id': 12589342,
#  'name': 'Manhattan',
#  'slug': 'manhattan-ny',
#  'short_name': 'Manhattan, NY',
#  'displayable_name': 'Manhattan, NY',
#  'localized_name': 'Manhattan',
#  'country': 'US',
#  'state': 'NY',
#  'type': 'County',
#  'is_root': False,
#  'urls': {'web': {'discover': 'https://www.kickstarter.com/discover/places/manhattan-ny',
#    'location': 'https://www.kickstarter.com/locations/manhattan-ny'},
#   'api': {'nearby_projects': 'https://api.kickstarter.com/v1/discover?signature=1539904398.aae3553d1e62a16aac55da44ac8c71966f64bb86&woe_id=12589342'}}}

# %%
# Useful keys: country, state

# %%
for x in range(0, len(json_obj3)):
    # Extract country and state data
    if "location" in json_obj2[x]:
        json_obj3[x]["loc_country"] = json_obj2[x]["location"]["country"]
        json_obj3[x]["loc_state"] = json_obj2[x]["location"]["state"]
    # Add NaN when country/state data does not exist
    else:
        json_obj3[x]["loc_country"] = float('NaN')
        json_obj3[x]["loc_state"] = float('NaN')

# %%
# ---- Explore 'category' ----

# %%
# Grab useful previously removed sub key-value pairs:
json_obj2[0]["category"].keys()
# Out:
# dict_keys(['id', 'name', 'slug', 'position', 'parent_id', 'color', 'urls'])

# %%
json_obj2[0]["category"]
# Out:
# {'id': 342,
#  'name': 'Web',
#  'slug': 'technology/web',
#  'position': 15,
#  'parent_id': 16,
#  'color': 6526716,
#  'urls': {'web': {'discover': 'http://www.kickstarter.com/discover/categories/technology/web'}}}

# %%
# Useful keys: name, slug, position, parent_id

# %%
# Check for null entries
x_category = 0
for x in range(0, len(json_obj2)):
    if "category" in json_obj2[x]:
        x_category = x_category + 1
    else:
        break
x_category - len(json_obj2)
# Out:
# 0

# %%
json_obj2[0]["category"]
# Out:
# {'id': 342,
#  'name': 'Web',
#  'slug': 'technology/web',
#  'position': 15,
#  'parent_id': 16,
#  'color': 6526716,
#  'urls': {'web': {'discover': 'http://www.kickstarter.com/discover/categories/technology/web'}}}

# %%
x_name = 0
for x in range(0, len(json_obj2)):
    if "name" in json_obj2[x]["category"]:
        x_name = x_name + 1
x_name - len(json_obj2)
# Out:
# 0

# %%
x_slug = 0
for x in range(0, len(json_obj2)):
    if "slug" in json_obj2[x]["category"]:
        x_slug = x_slug + 1
x_slug - len(json_obj2)
# Out:
# 0

# %%
x_position = 0
for x in range(0, len(json_obj2)):
    if "position" in json_obj2[x]["category"]:
        x_position = x_position + 1
x_position - len(json_obj2)
# Out:
# 0

# %%
x_parent_id = 0
for x in range(0, len(json_obj2)):
    if "parent_id" in json_obj2[x]["category"]:
        x_parent_id = x_parent_id + 1
x_parent_id - len(json_obj2)
# Out:
# -17378

# %%
# NOTE: parent_id has 17378 null values!

# %%
for x in range(0, len(json_obj3)):
    # Extract name, slug, position, and parent_id data
    json_obj3[x]["category_name"] = json_obj2[x]["category"]["name"]
    json_obj3[x]["category_slug"] = json_obj2[x]["category"]["slug"]
    json_obj3[x]["category_position"] = json_obj2[x]["category"]["position"]
    if "parent_id" in json_obj2[x]["category"]:
        json_obj3[x]["category_parent_id"] = json_obj2[x]["category"]["parent_id"]
    # Add NaN when data does not exist
    else:
        json_obj3[x]["category_parent_id"] = float('NaN')

# %%
json_obj3[0]
# Out:
# {'id': 895922629,
#  'name': 'Jozii-College Jobs Made Easy',
#  'blurb': 'Jozii is the premier service for full-time university students to find paid part-time work and internships.',
#  'goal': 3500,
#  'pledged': 50,
#  'state': 'failed',
#  'disable_communication': False,
#  'country': 'US',
#  'currency': 'USD',
#  'currency_symbol': '$',
#  'currency_trailing_code': True,
#  'deadline': 1417150740,
#  'state_changed_at': 1417150742,
#  'created_at': 1413476386,
#  'launched_at': 1414525374,
#  'staff_pick': False,
#  'is_starrable': False,
#  'backers_count': 1,
#  'static_usd_rate': 1,
#  'usd_pledged': '50.0',
#  'converted_pledged_amount': 50,
#  'fx_rate': 1,
#  'current_currency': 'USD',
#  'usd_type': 'international',
#  'spotlight': False,
#  'creator_registered': True,
#  'loc_country': 'US',
#  'loc_state': 'NY',
#  'category_name': 'Web',
#  'category_slug': 'technology/web',
#  'category_position': 15,
#  'category_parent_id': 16}

# %%
# ---- Explore 'profile' ----

# %%
# Grab useful previously removed sub key-value pairs:
json_obj2[0]["profile"].keys()
# Out:
# dict_keys(['id', 'project_id', 'state', 'state_changed_at', 'name', 'blurb', 'background_color', 'text_color', 'link_background_color', 'link_text_color', 'link_text', 'link_url', 'show_feature_image', 'background_image_opacity', 'should_show_feature_image_section', 'feature_image_attributes'])

# %%
json_obj2[56037]["profile"]
# Out:
# {'id': 1841891,
#  'project_id': 1841891,
#  'state': 'inactive',
#  'state_changed_at': 1429068314,
#  'name': None,
#  'blurb': None,
#  'background_color': None,
#  'text_color': None,
#  'link_background_color': None,
#  'link_text_color': None,
#  'link_text': None,
#  'link_url': None,
#  'show_feature_image': False,
#  'background_image_opacity': 0.8,
#  'should_show_feature_image_section': True,
#  'feature_image_attributes': {'image_urls': {'default': 'https://ksr-ugc.imgix.net/assets/012/107/897/fa251d5986d6744d80e917ce8402ae0b_original.jpg?ixlib=rb-1.1.0&crop=faces&w=1552&h=873&fit=crop&v=1463737460&auto=format&frame=1&q=92&s=3417203c5d3a4e034ffc31fa89c1c892',
#    'baseball_card': 'https://ksr-ugc.imgix.net/assets/012/107/897/fa251d5986d6744d80e917ce8402ae0b_original.jpg?ixlib=rb-1.1.0&crop=faces&w=560&h=315&fit=crop&v=1463737460&auto=format&frame=1&q=92&s=ddce863a58a3fae73b17d0e6610a85a2'}}}

# %%
json_obj2[4]["profile"]["state"]
# Out:
# 'active'

# %%
# check to see how many profile states are 'inactive'
x_inactive = 0
for x in range(0, len(json_obj2)):
    if json_obj2[x]["profile"]["state"] == 'inactive':
        x_inactive += 1
x_inactive
# Out:
# 181513

# %%
# check to see how many profile states are 'active'
x_active = 0
for x in range(0, len(json_obj2)):
    if json_obj2[x]["profile"]["state"] == 'active':
        x_active += 1
x_active
# Out:
# 24183

# %%
len(json_obj2) - x_active - x_inactive
# Out:
# 0

# %%
# There are only two options for state: active and inactive - there are many inactive profile states

# %%
# Useful keys: none
# This is a bit of a guess. Most of the profile states are labeled as 'inactive'.
# My guess is that the profiles go latent once a projct is finished (perhaps regardless of whether it was successful or not)

# %%
# ---- CONVERT TO DATA FRAME ----

# %%
json_obj3[0]
# Out:
# {'id': 895922629,
#  'name': 'Jozii-College Jobs Made Easy',
#  'blurb': 'Jozii is the premier service for full-time university students to find paid part-time work and internships.',
#  'goal': 3500,
#  'pledged': 50,
#  'state': 'failed',
#  'disable_communication': False,
#  'country': 'US',
#  'currency': 'USD',
#  'currency_symbol': '$',
#  'currency_trailing_code': True,
#  'deadline': 1417150740,
#  'state_changed_at': 1417150742,
#  'created_at': 1413476386,
#  'launched_at': 1414525374,
#  'staff_pick': False,
#  'is_starrable': False,
#  'backers_count': 1,
#  'static_usd_rate': 1,
#  'usd_pledged': '50.0',
#  'converted_pledged_amount': 50,
#  'fx_rate': 1,
#  'current_currency': 'USD',
#  'usd_type': 'international',
#  'spotlight': False,
#  'creator_registered': True,
#  'loc_country': 'US',
#  'loc_state': 'NY',
#  'category_name': 'Web',
#  'category_slug': 'technology/web',
#  'category_position': 15,
#  'category_parent_id': 16}

# %%
len(json_obj3)
# Out:
# 205696

# %%
df = pd.DataFrame.from_records(json_obj3)
df.head()
# Out:
#    backers_count                                              blurb  \
# 0              1  Jozii is the premier service for full-time uni...
# 1             63  Dropsy is an adventure game with a focus on ex...
# 2            113  We've bought a press and already found a studi...
# 3              1  Premium, fashion sneaker brand intertwining hi...
# 4             99  Made in Europe from the finest quality leather...
#
#   category_name  category_parent_id  category_position  \
# 0           Web                16.0                 15
# 1   Video Games                12.0                  7
# 2   Letterpress                18.0                  7
# 3      Footwear                 9.0                  5
# 4      Footwear                 9.0                  5
#
#             category_slug  converted_pledged_amount country  created_at  \
# 0          technology/web                        50      US  1413476386
# 1       games/video games                      1613      US  1317217452
# 2  publishing/letterpress                      6633      US  1403324529
# 3        fashion/footwear                         1      GB  1457103832
# 4        fashion/footwear                     20654      CA  1423776567
#
#    creator_registered      ...       loc_state  \
# 0                True      ...              NY
# 1                True      ...              FL
# 2                True      ...              OR
# 3                True      ...         England
# 4                True      ...              ON
#
#                                                 name   pledged spotlight  \
# 0                       Jozii-College Jobs Made Easy     50.00     False
# 1  DROPSY: A different take on the old school adv...   1613.47      True
# 2  Letra Chueca / Crooked Letter: a printshop & b...   6633.00      True
# 3                 High End Premium Handmade Sneakers      1.00     False
# 4      The Domenico Sneakerboot by Luigi Sardo Shoes  25338.00      True
#
#    staff_pick       state  state_changed_at  static_usd_rate     usd_pledged  \
# 0       False      failed        1417150742         1.000000            50.0
# 1        True  successful        1320259153         1.000000         1613.47
# 2       False  successful        1410502338         1.000000          6633.0
# 3       False      failed        1462305856         1.407899      1.40789944
# 4       False  successful        1429678899         0.782122  19817.40571572
#
#         usd_type
# 0  international
# 1  international
# 2  international
# 3  international
# 4  international
#
# [5 rows x 32 columns]

# %%
df.tail()
# Out:
#         backers_count                                              blurb  \
# 205691             66  Re: Magazine is the Savannah College of Art an...
# 205692            113  Due to popularity, demand, and based on feedba...
# 205693            259  An epic and timeless hand illustrated deck of ...
# 205694              2                     The slasher film has returned.
# 205695              3  We are opening what we hope will be a wonderfu...
#
#         category_name  category_parent_id  category_position  \
# 205691    Periodicals                18.0                 10
# 205692         Events                 3.0                  3
# 205693  Playing Cards                12.0                  4
# 205694         Horror                11.0                 10
# 205695    Restaurants                10.0                  9
#
#                  category_slug  converted_pledged_amount country  created_at  \
# 205691  publishing/periodicals                      4846      US  1329261163
# 205692           comics/events                      8596      GB  1389612547
# 205693     games/playing cards                      7623      US  1409509864
# 205694     film & video/horror                        80      US  1475388732
# 205695        food/restaurants                        35      US  1405914894
#
#         creator_registered      ...       loc_state  \
# 205691                True      ...              GA
# 205692                True      ...         England
# 205693                True      ...              FL
# 205694                True      ...              OH
# 205695                True      ...              TX
#
#                                                    name  pledged spotlight  \
# 205691                                     Re: Magazine  4846.79      True
# 205692         Melksham Comic Con 2014 - The Expansion!  5186.50      True
# 205693      A Deck of Skeletons. Vintage Playing Cards.  7623.00      True
# 205694                           I'm Scared - Inde Film    80.00     False
# 205695  Get Hula Cowgirl Shaved Ice Over the Last Bump!    35.00     False
#
#         staff_pick       state  state_changed_at  static_usd_rate  \
# 205691        True  successful        1330664342         1.000000
# 205692       False  successful        1396700229         1.668265
# 205693       False  successful        1412891110         1.000000
# 205694       False      failed        1477985542         1.000000
# 205695       False      failed        1408057020         1.000000
#
#           usd_pledged       usd_type
# 205691        4846.79  international
# 205692  8652.45860083  international
# 205693         7623.0  international
# 205694           80.0  international
# 205695           35.0  international
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205696 entries, 0 to 205695
# Data columns (total 32 columns):
# backers_count               205696 non-null int64
# blurb                       205696 non-null object
# category_name               205696 non-null object
# category_parent_id          188318 non-null float64
# category_position           205696 non-null int64
# category_slug               205696 non-null object
# converted_pledged_amount    205696 non-null int64
# country                     205696 non-null object
# created_at                  205696 non-null int64
# creator_registered          205696 non-null bool
# currency                    205696 non-null object
# currency_symbol             205696 non-null object
# currency_trailing_code      205696 non-null bool
# current_currency            205696 non-null object
# deadline                    205696 non-null int64
# disable_communication       205696 non-null bool
# fx_rate                     205696 non-null float64
# goal                        205696 non-null float64
# id                          205696 non-null int64
# is_starrable                205696 non-null bool
# launched_at                 205696 non-null int64
# loc_country                 204404 non-null object
# loc_state                   204352 non-null object
# name                        205696 non-null object
# pledged                     205696 non-null float64
# spotlight                   205696 non-null bool
# staff_pick                  205696 non-null bool
# state                       205696 non-null object
# state_changed_at            205696 non-null int64
# static_usd_rate             205696 non-null float64
# usd_pledged                 205696 non-null object
# usd_type                    203968 non-null object
# dtypes: bool(6), float64(5), int64(8), object(13)
# memory usage: 42.0+ MB

# %%
df.describe()
# Out:
#        backers_count  category_parent_id  category_position  \
# count  205696.000000       188318.000000      205696.000000
# mean      146.106132           11.782331           7.137514
# std      1033.317310            5.540618           4.575614
# min         0.000000            1.000000           1.000000
# 25%         4.000000           10.000000           3.000000
# 50%        27.000000           12.000000           6.000000
# 75%        85.000000           16.000000          10.000000
# max    105857.000000           26.000000          19.000000
#
#        converted_pledged_amount    created_at      deadline        fx_rate  \
# count              2.056960e+05  2.056960e+05  2.056960e+05  205696.000000
# mean               1.223341e+04  1.412305e+09  1.418814e+09       1.003671
# std                9.256958e+04  7.025463e+07  7.041752e+07       0.197427
# min                0.000000e+00  1.240335e+09  1.241334e+09       0.008886
# 25%                1.100000e+02  1.358319e+09  1.365907e+09       1.000000
# 50%                1.558000e+03  1.415725e+09  1.423431e+09       1.000000
# 75%                6.220000e+03  1.463547e+09  1.470328e+09       1.000000
# max                1.026684e+07  1.539821e+09  1.545013e+09      10.268501
#
#                goal            id   launched_at       pledged  \
# count  2.056960e+05  2.056960e+05  2.056960e+05  2.056960e+05
# mean   4.513457e+04  1.074607e+09  1.415885e+09  1.373092e+04
# std    1.141468e+06  6.190907e+08  7.056412e+07  1.346135e+05
# min    1.000000e-02  1.852000e+04  1.240603e+09  0.000000e+00
# 25%    1.500000e+03  5.379528e+08  1.363131e+09  1.100000e+02
# 50%    5.000000e+03  1.077976e+09  1.420672e+09  1.560320e+03
# 75%    1.340000e+04  1.608983e+09  1.467530e+09  6.300000e+03
# max    1.000000e+08  2.147476e+09  1.539838e+09  2.334387e+07
#
#        state_changed_at  static_usd_rate
# count      2.056960e+05    205696.000000
# mean       1.418616e+09         1.017976
# std        7.018238e+07         0.201805
# min        1.241334e+09         0.008771
# 25%        1.365890e+09         1.000000
# 50%        1.423275e+09         1.000000
# 75%        1.470191e+09         1.000000
# max        1.539839e+09         1.716408

# %%
len(json_obj3[0])
# Out:
# 32

# %%
len(df.columns)
# Out:
# 32

# %%
# ========================================
# CLEAN DATA
# ========================================

# %%
# ---- REARRANGE COLUMNS ----
df.columns
# Out:
# Index(['backers_count', 'blurb', 'category_name', 'category_parent_id',
#        'category_position', 'category_slug', 'converted_pledged_amount',
#        'country', 'created_at', 'creator_registered', 'currency',
#        'currency_symbol', 'currency_trailing_code', 'current_currency',
#        'deadline', 'disable_communication', 'fx_rate', 'goal', 'id',
#        'is_starrable', 'launched_at', 'loc_country', 'loc_state', 'name',
#        'pledged', 'spotlight', 'staff_pick', 'state', 'state_changed_at',
#        'static_usd_rate', 'usd_pledged', 'usd_type'],
#       dtype='object')

# %%
json_obj3[0].keys()
# Out:
# dict_keys(['id', 'name', 'blurb', 'goal', 'pledged', 'state', 'disable_communication', 'country', 'currency', 'currency_symbol', 'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at', 'launched_at', 'staff_pick', 'is_starrable', 'backers_count', 'static_usd_rate', 'usd_pledged', 'converted_pledged_amount', 'fx_rate', 'current_currency', 'usd_type', 'spotlight', 'creator_registered', 'loc_country', 'loc_state', 'category_name', 'category_slug', 'category_position', 'category_parent_id'])

# %%
df = df[['id', 'name', 'blurb', 'category_name', 'category_slug', 'category_position', 'category_parent_id', 'goal', 'pledged', 
         'disable_communication', 'loc_country', 'loc_state', 'country', 'currency', 'currency_symbol', 'currency_trailing_code', 'deadline', 
         'state_changed_at', 'created_at', 'launched_at', 'staff_pick', 'is_starrable', 'backers_count', 'static_usd_rate', 
         'usd_pledged', 'converted_pledged_amount', 'fx_rate', 'current_currency', 'usd_type', 'spotlight', 
         'creator_registered', 'state']]

# %%
df.columns
# Out:
# Index(['id', 'name', 'blurb', 'category_name', 'category_slug',
#        'category_position', 'category_parent_id', 'goal', 'pledged',
#        'disable_communication', 'loc_country', 'loc_state', 'country',
#        'currency', 'currency_symbol', 'currency_trailing_code', 'deadline',
#        'state_changed_at', 'created_at', 'launched_at', 'staff_pick',
#        'is_starrable', 'backers_count', 'static_usd_rate', 'usd_pledged',
#        'converted_pledged_amount', 'fx_rate', 'current_currency', 'usd_type',
#        'spotlight', 'creator_registered', 'state'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 32

# %%
# ---- REMOVE DUPLICATES ----

# %%
df.sort_values(by=["backers_count"],ascending=False)[["id","name","backers_count"]]
# Out:
#                 id                                               name  \
# 69279    557230947  Bring Reading Rainbow Back for Every Child, Ev...
# 188496   557230947  Bring Reading Rainbow Back for Every Child, Ev...
# 150213  1755266685                    The Veronica Mars Movie Project
# 13732   1929840910                              Double Fine Adventure
# 53281   1929840910                              Double Fine Adventure
# 129025   286165030                         Torment: Tides of Numenera
# 136791   286165030                         Torment: Tides of Numenera
# 186022   458565935                                   Project Eternity
# 141451   458565935                                   Project Eternity
# 174366  1194278206         Yooka-Laylee - A 3D Platformer Rare-vival!
# 114940   947809001                                          Shenmue 3
# 150531   506924864       Pebble: E-Paper Watch for iPhone and Android
# 80539    506924864       Pebble: E-Paper Watch for iPhone and Android
# 72627    564596765                                       Mighty No. 9
# 78658   1074800880                  Bloodstained: Ritual of the Night
# 179857  1033978702             OUYA: A New Kind of Video Game Console
# 183540  1033978702             OUYA: A New Kind of Video Game Console
# 75344   2000827215                                        Wasteland 2
# 173782  2000827215                                        Wasteland 2
# 68972   1454565733            Bring Back MYSTERY SCIENCE THEATER 3000
# 156706  1871494789                                    WISH I WAS HERE
# 23258   1957695328     Planetary Annihilation - A Next Generation RTS
# 48858   1957695328     Planetary Annihilation - A Next Generation RTS
# 67661    275698538                           Divinity: Original Sin 2
# 179190   474183945                                         BATTLETECH
# 108310  1552929469      CHIP - The World's First Nine Dollar Computer
# 110161   577817754  PINE A64, First $15 64-Bit Single Board Super ...
# 44394    531044328                                  Shadowrun Returns
# 39514    531044328                                  Shadowrun Returns
# 136348  1918188380                                     Font Awesome 5
# ...            ...                                                ...
# 52091    135415487  Mammilaki Handcrafted wooden sunglasses (Cance...
# 52093   1820151576                                            BACON!!
# 52096    712810035                            BATTLEGROUNDS COMP 2014
# 52098    734086209                                     Not The Birds!
# 170785  1928050075                                      Cindos Quilts
# 110979  1933964213      Honest, Equitable, and Balanced News Channel.
# 110969   173301675                        Tartarus, Fall of an Empire
# 189367   820992510                                         Hair Booth
# 111029   390692844                                          #crimetag
# 170772  1214372847                                     Luxe Bracelets
# 111043  1058499667                     Rise To The Prize! (Game Show)
# 111044  1572774173                              PremierThreadsCompany
# 189416  1948581729                                 A Haunted Hangover
# 111092  2053754055                                 The Consuela Show!
# 170748   171033191                                   BORDERED BOTTLES
# 111087  1003366986    SOMASOL Vegan Balms Production Space (Canceled)
# 51972    431328886  LOTUS Life Learning - Personal Empowerment for...
# 51975    712996656            Free Wind Chime Designs and Commissions
# 111078  1623243897                               Less Than Three (<3)
# 111075  1180975882                                   Portal to Alaska
# 111074  1871460841                           Book VS Cover (Canceled)
# 111065   917876122                    All Things Cryptocurrency - ATC
# 111058  2005180407                                         T.S. Teens
# 111049  2026472919                     Allergist on Demand (Canceled)
# 52016   1572474304                                      FIRE EXPLORER
# 52019    773491825                                        Cop filming
# 111048  1510249869                    Professor Byers Elixirs & Balms
# 52023   1726689593  kush kid collectiblez is a clothing line for t...
# 52029    519956154      Anyone Can Be An Astronaut; Summer Collection
# 41874   1987095871                                           Au Solar
#
#         backers_count
# 69279          105857
# 188496         105857
# 150213          91585
# 13732           87142
# 53281           87142
# 129025          74405
# 136791          74405
# 186022          73986
# 141451          73986
# 174366          73206
# 114940          69320
# 150531          68929
# 80539           68929
# 72627           67226
# 78658           64867
# 179857          63416
# 183540          63416
# 75344           61290
# 173782          61290
# 68972           48270
# 156706          46520
# 23258           44162
# 48858           44162
# 67661           42713
# 179190          41733
# 108310          39560
# 110161          36781
# 44394           36276
# 39514           36276
# 136348          35550
# ...               ...
# 52091               0
# 52093               0
# 52096               0
# 52098               0
# 170785              0
# 110979              0
# 110969              0
# 189367              0
# 111029              0
# 170772              0
# 111043              0
# 111044              0
# 189416              0
# 111092              0
# 170748              0
# 111087              0
# 51972               0
# 51975               0
# 111078              0
# 111075              0
# 111074              0
# 111065              0
# 111058              0
# 111049              0
# 52016               0
# 52019               0
# 111048              0
# 52023               0
# 52029               0
# 41874               0
#
# [205696 rows x 3 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (189240, 32)

# %%
# We dropped 205696-189240=16456 duplicate rows

# %%
# Search for more duplicates
len(df["id"].unique()) - len(df)
# Out:
# -2166

# %%
# There are still 2166 duplicate IDs

# %%
# Explore the duplicate ID rows
pd.concat(g for _, g in df.groupby("id") if len(g) > 1)
# Out:
#                 id                                               name  \
# 10531       422207  The Arduino Compatible Educational Sensor Lear...
# 69099       422207  The Arduino Compatible Educational Sensor Lear...
# 184333     1033120  Fields of Fire: Miniatures rules for modern co...
# 204054     1033120  Fields of Fire: Miniatures rules for modern co...
# 83960      2705005  LOVE MEI waterproof case, protect iPhone X/Xs ...
# 203854     2705005  LOVE MEI waterproof case, protect iPhone X/Xs ...
# 67679      4534946                            'Skin Walkers' knit FMP
# 160239     4534946                            'Skin Walkers' knit FMP
# 84917      5090855                               Charmed Flying Broom
# 105652     5090855                               Charmed Flying Broom
# 27985      5353475        Race the Sun - An Infinite Speed Experience
# 162084     5353475        Race the Sun - An Infinite Speed Experience
# 64961      5780295                             Refrigerator Simulator
# 121955     5780295                             Refrigerator Simulator
# 171904     8412272  The ultimate music performance machine for stu...
# 205007     8412272  The ultimate music performance machine for stu...
# 72812      8688135                          QU3UE AN ESPORTS PARADISE
# 106469     8688135                          QU3UE AN ESPORTS PARADISE
# 52566      8747999  Soul Entendre: LAUNCH COLLECTION | Streetwear ...
# 95609      8747999  Soul Entendre: LAUNCH COLLECTION | Streetwear ...
# 1030       9888853           Watch Your Mouth ... And Throw An F-Bomb
# 83031      9888853           Watch Your Mouth ... And Throw An F-Bomb
# 40734     12803820    Going International - Global Fashion Expedition
# 191650    12803820    Going International - Global Fashion Expedition
# 105318    13539350  GodFire Apparel : You have a story. We have a ...
# 160257    13539350  GodFire Apparel : You have a story. We have a ...
# 65687     14064883  Wild Assent - Survive the Arena and Tame the W...
# 91937     14064883  Wild Assent - Survive the Arena and Tame the W...
# 24068     15036961               Vortex: A handmade glass collection.
# 181754    15036961               Vortex: A handmade glass collection.
# ...            ...                                                ...
# 204157  2133187312                                         Mana Crypt
# 205551  2133187312                                         Mana Crypt
# 18192   2133832079                       Final Element the Video Game
# 198665  2133832079                       Final Element the Video Game
# 29566   2134104708  Curvy Cosplay: Custom Patterns & Costumes for ...
# 179553  2134104708  Curvy Cosplay: Custom Patterns & Costumes for ...
# 79533   2137724959  Empower Arts Magazine: Celebrating the healing...
# 159346  2137724959  Empower Arts Magazine: Celebrating the healing...
# 13940   2137727326                              The Production Studio
# 85826   2137727326                              The Production Studio
# 33248   2137911646                                       Hora Azulona
# 190799  2137911646                                       Hora Azulona
# 64796   2138176669      Something Terrible: An Exercise in Inadequacy
# 96690   2138176669      Something Terrible: An Exercise in Inadequacy
# 187107  2141207772                                 Gnomes at Midnight
# 193423  2141207772                                 Gnomes at Midnight
# 15320   2141519698  CharlieYipBrand: Minimalist Leather Wallets & ...
# 166362  2141519698  CharlieYipBrand: Minimalist Leather Wallets & ...
# 21482   2142171940  HDMIPi Affordable 9" High-Def screen for the R...
# 25143   2142171940  HDMIPi Affordable 9" High-Def screen for the R...
# 119055  2142218219     Quopener - The new effortless way to open jars
# 191184  2142218219     Quopener - The new effortless way to open jars
# 105159  2144192426                                  THRESHOLD: ALLURE
# 163626  2144192426                                  THRESHOLD: ALLURE
# 2973    2144932149      Create personalized boutique-quality jewelry!
# 100227  2144932149      Create personalized boutique-quality jewelry!
# 59526   2146692994  Anne Fogarty: Buy a Dress Bring Back a Fashion...
# 133960  2146692994  Anne Fogarty: Buy a Dress Bring Back a Fashion...
# 168921  2147339483                                Movema Dance Studio
# 178641  2147339483                                Movema Dance Studio
#
#                                                     blurb   category_name  \
# 10531   This arduino / Raspberry Pi compatible board s...        Hardware
# 69099   This arduino / Raspberry Pi compatible board s...        Hardware
# 184333  With this simple, yet realistic rules compilat...  Tabletop Games
# 204054  With this simple, yet realistic rules compilat...  Tabletop Games
# 83960   This IP68 Waterproof Case for iPhone X/Xs, wit...         Gadgets
# 203854  This IP68 Waterproof Case for iPhone X/Xs, wit...         Gadgets
# 67679   I'm a third year student currently designing &...         Couture
# 160239  I'm a third year student currently designing &...         Couture
# 84917   A spooky horror Halloween old school 3D platfo...     Video Games
# 105652  A spooky horror Halloween old school 3D platfo...     Video Games
# 27985   Intense racing through infinite sandbox worlds...     Video Games
# 162084  Intense racing through infinite sandbox worlds...     Video Games
# 64961   A quirky mobile puzzle game where you play wit...    Mobile Games
# 121955  A quirky mobile puzzle game where you play wit...    Mobile Games
# 171904  Pipes is a new audio platform which out-horsep...        Hardware
# 205007  Pipes is a new audio platform which out-horsep...        Hardware
# 72812   QU3UE is creating a 10,000 sq. ft. esports fac...      Live Games
# 106469  QU3UE is creating a 10,000 sq. ft. esports fac...      Live Games
# 52566   Quality (Made in the USA), comfortable, and ey...         Apparel
# 95609   Quality (Made in the USA), comfortable, and ey...         Apparel
# 1030    This is the launch of a new item to help grow ...         Crochet
# 83031   This is the launch of a new item to help grow ...         Crochet
# 40734   A documentary consisting of various events, un...          People
# 191650  A documentary consisting of various events, un...          People
# 105318  Apparel that gives back and shares incredible ...         Apparel
# 160257  Apparel that gives back and shares incredible ...         Apparel
# 65687   A 1-4 player board game with solo/cooperative ...  Tabletop Games
# 91937   A 1-4 player board game with solo/cooperative ...  Tabletop Games
# 24068   A collection of handmade glass vases and sea s...           Glass
# 181754  A collection of handmade glass vases and sea s...           Glass
# ...                                                   ...             ...
# 204157  Venture into the Crypt. Build a deck, bury you...  Tabletop Games
# 205551  Venture into the Crypt. Build a deck, bury you...  Tabletop Games
# 18192   Think Megaman X meets Metal Slug meets Turtles...     Video Games
# 198665  Think Megaman X meets Metal Slug meets Turtles...     Video Games
# 29566   Custom drafted patterns and costumes made for ...         Couture
# 179553  Custom drafted patterns and costumes made for ...         Couture
# 79533   Empower Arts is a publication dedicated to tel...     Periodicals
# 159346  Empower Arts is a publication dedicated to tel...     Periodicals
# 13940   The Production Studio is looking to become a l...        Fine Art
# 85826   The Production Studio is looking to become a l...        Fine Art
# 33248   Porque Getafe tiene afición y hacemos radio pa...           Audio
# 190799  Porque Getafe tiene afición y hacemos radio pa...           Audio
# 64796   A callback to the Atari age of gaming; when th...     Video Games
# 96690   A callback to the Atari age of gaming; when th...     Video Games
# 187107  A 2-player, light strategy, kind-hearted, fun ...  Tabletop Games
# 193423  A 2-player, light strategy, kind-hearted, fun ...  Tabletop Games
# 15320   This project aims towards the functionality of...     Accessories
# 166362  This project aims towards the functionality of...     Accessories
# 21482   Small HDMI screens are  expensive. Native HD o...        Hardware
# 25143   Small HDMI screens are  expensive. Native HD o...        Hardware
# 119055  It's never been easier to open jars. With the ...  Product Design
# 191184  It's never been easier to open jars. With the ...  Product Design
# 105159             Threshold returns!  Introducing Praxi!     Comic Books
# 163626             Threshold returns!  Introducing Praxi!     Comic Books
# 2973    Create wearable memories with affordable jewel...         Jewelry
# 100227  Create wearable memories with affordable jewel...         Jewelry
# 59526   After 34 years the Anne Fogarty label is back....         Apparel
# 133960  After 34 years the Anne Fogarty label is back....         Apparel
# 168921  With your support, Movema can relocate to offi...          Spaces
# 178641  With your support, Movema can relocate to offi...          Spaces
#
#                  category_slug  category_position  category_parent_id  \
# 10531      technology/hardware                  8                16.0
# 69099      technology/hardware                  8                16.0
# 184333    games/tabletop games                  6                12.0
# 204054    games/tabletop games                  6                12.0
# 83960       technology/gadgets                  7                16.0
# 203854      technology/gadgets                  7                16.0
# 67679          fashion/couture                  4                 9.0
# 160239         fashion/couture                  4                 9.0
# 84917        games/video games                  7                12.0
# 105652       games/video games                  7                12.0
# 27985        games/video games                  7                12.0
# 162084       games/video games                  7                12.0
# 64961       games/mobile games                  3                12.0
# 121955      games/mobile games                  3                12.0
# 171904     technology/hardware                  8                16.0
# 205007     technology/hardware                  8                16.0
# 72812         games/live games                  2                12.0
# 106469        games/live games                  2                12.0
# 52566          fashion/apparel                  2                 9.0
# 95609          fashion/apparel                  2                 9.0
# 1030            crafts/crochet                  2                26.0
# 83031           crafts/crochet                  2                26.0
# 40734       photography/people                  4                15.0
# 191650      photography/people                  4                15.0
# 105318         fashion/apparel                  2                 9.0
# 160257         fashion/apparel                  2                 9.0
# 65687     games/tabletop games                  6                12.0
# 91937     games/tabletop games                  6                12.0
# 24068             crafts/glass                  5                26.0
# 181754            crafts/glass                  5                26.0
# ...                        ...                ...                 ...
# 204157    games/tabletop games                  6                12.0
# 205551    games/tabletop games                  6                12.0
# 18192        games/video games                  7                12.0
# 198665       games/video games                  7                12.0
# 29566          fashion/couture                  4                 9.0
# 179553         fashion/couture                  4                 9.0
# 79533   publishing/periodicals                 10                18.0
# 159346  publishing/periodicals                 10                18.0
# 13940     photography/fine art                  2                15.0
# 85826     photography/fine art                  2                15.0
# 33248         journalism/audio                  1                13.0
# 190799        journalism/audio                  1                13.0
# 64796        games/video games                  7                12.0
# 96690        games/video games                  7                12.0
# 187107    games/tabletop games                  6                12.0
# 193423    games/tabletop games                  6                12.0
# 15320      fashion/accessories                  1                 9.0
# 166362     fashion/accessories                  1                 9.0
# 21482      technology/hardware                  8                16.0
# 25143      technology/hardware                  8                16.0
# 119055   design/product design                  5                 7.0
# 191184   design/product design                  5                 7.0
# 105159      comics/comic books                  2                 3.0
# 163626      comics/comic books                  2                 3.0
# 2973           fashion/jewelry                  6                 9.0
# 100227         fashion/jewelry                  6                 9.0
# 59526          fashion/apparel                  2                 9.0
# 133960         fashion/apparel                  2                 9.0
# 168921            dance/spaces                  3                 6.0
# 178641            dance/spaces                  3                 6.0
#
#             goal    pledged  disable_communication     ...     backers_count  \
# 10531     1200.0    7728.00                  False     ...               180
# 69099     1200.0    7728.00                  False     ...               180
# 184333    2500.0    2575.00                  False     ...                35
# 204054    2500.0    2575.00                  False     ...                35
# 83960    24000.0    1110.00                  False     ...                11
# 203854   24000.0    1110.00                  False     ...                11
# 67679       50.0      85.00                  False     ...                 6
# 160239      50.0      85.00                  False     ...                 6
# 84917   250000.0     418.80                  False     ...                 2
# 105652  250000.0     418.80                  False     ...                 2
# 27985    20000.0   21579.48                  False     ...              1144
# 162084   20000.0   21579.48                  False     ...              1144
# 64961     2500.0     526.00                  False     ...                25
# 121955    2500.0     526.00                  False     ...                25
# 171904  100000.0  106609.00                  False     ...               243
# 205007  100000.0  107407.00                  False     ...               245
# 72812   125000.0    6834.00                  False     ...                34
# 106469  125000.0    6834.00                  False     ...                34
# 52566     5000.0    6963.00                  False     ...                81
# 95609     5000.0    6963.00                  False     ...                81
# 1030       100.0     935.00                  False     ...                33
# 83031      100.0     935.00                  False     ...                33
# 40734     1000.0    1005.00                  False     ...                17
# 191650    1000.0    1005.00                  False     ...                17
# 105318   10000.0   10981.00                  False     ...               116
# 160257   10000.0   10981.00                  False     ...               116
# 65687    70000.0  253377.00                  False     ...              1612
# 91937    70000.0  254472.00                  False     ...              1619
# 24068      500.0    2317.00                  False     ...                47
# 181754     500.0    2317.00                  False     ...                47
# ...          ...        ...                    ...     ...               ...
# 204157    3000.0    2243.00                  False     ...                81
# 205551    3000.0    2243.00                  False     ...                81
# 18192     1000.0    1664.00                  False     ...               159
# 198665    1000.0    1664.00                  False     ...               159
# 29566     2000.0    2127.00                  False     ...                29
# 179553    2000.0    2127.00                  False     ...                29
# 79533      500.0    1082.00                  False     ...                38
# 159346     500.0    1082.00                  False     ...                38
# 13940     3000.0    3451.00                  False     ...                11
# 85826     3000.0    3451.00                  False     ...                11
# 33248      600.0    1304.00                  False     ...                30
# 190799     600.0    1304.00                  False     ...                30
# 64796      113.0      12.29                  False     ...                 9
# 96690      113.0      12.29                  False     ...                 9
# 187107   12750.0    3339.29                  False     ...                76
# 193423   12750.0    3339.29                  False     ...                76
# 15320     2500.0    2592.00                  False     ...                57
# 166362    2500.0    2592.00                  False     ...                57
# 21482    55000.0  261250.46                  False     ...              2523
# 25143    55000.0  261250.46                  False     ...              2523
# 119055   60000.0    5220.00                  False     ...               118
# 191184   60000.0    5220.00                  False     ...               118
# 105159    1800.0    8698.00                  False     ...               115
# 163626    1800.0    8734.00                  False     ...               117
# 2973     25000.0   25766.00                  False     ...               189
# 100227   25000.0   25766.00                  False     ...               189
# 59526    30000.0   30062.00                  False     ...                90
# 133960   30000.0   30062.00                  False     ...                90
# 168921    3000.0    3320.00                  False     ...                56
# 178641    3000.0    3320.00                  False     ...                56
#
#        static_usd_rate        usd_pledged converted_pledged_amount   fx_rate  \
# 10531         0.911649      7045.22602224                     6951  0.771892
# 69099         0.911649      7045.22602224                     6951  0.766650
# 184333        1.000000             2575.0                     2575  1.000000
# 204054        1.000000             2575.0                     3358  1.304376
# 83960         0.128052        142.1373093                      141  0.127570
# 203854        0.128006        142.0867266                      141  0.127570
# 67679         1.683130       143.06609165                      144  1.317483
# 160239        1.683130       143.06609165                      145  1.708667
# 84917         0.053033       22.210417236                       22  0.052969
# 105652        0.053033       22.210417236                       33  0.080902
# 27985         1.000000           21579.48                    21579  1.000000
# 162084        1.000000           21579.48                    28147  1.304376
# 64961         1.000000              526.0                      526  1.000000
# 121955        1.000000              526.0                      526  1.000000
# 171904        1.000000           106609.0                   106609  1.000000
# 205007        1.000000           107407.0                   107407  1.000000
# 72812         1.000000             6834.0                     6834  1.000000
# 106469        1.000000             6834.0                     6834  1.000000
# 52566         1.000000             6963.0                     9082  1.304376
# 95609         1.000000             6963.0                     6963  1.000000
# 1030          0.732279       684.68072475                      692  0.771892
# 83031         0.732279       684.68072475                      692  0.766650
# 40734         0.915599       920.17714575                      922  0.766650
# 191650        0.915599       920.17714575                      922  0.771892
# 105318        1.000000            10981.0                    10981  1.000000
# 160257        1.000000            10981.0                    14323  1.304376
# 65687         1.000000           253377.0                   253377  1.000000
# 91937         1.000000           254472.0                   254472  1.000000
# 24068         1.377997      3192.81897949                     3142  1.309950
# 181754        1.377997      3192.81897949                     3142  1.317483
# ...                ...                ...                      ...       ...
# 204157        1.000000             2243.0                     2243  1.000000
# 205551        1.000000             2243.0                     2243  1.000000
# 18192         1.000000             1664.0                     2170  1.304376
# 198665        1.000000             1664.0                     1664  1.000000
# 29566         1.000000             2127.0                     2127  1.000000
# 179553        1.000000             2127.0                     2774  1.304376
# 79533         1.293214      1399.25794834                     1417  1.309950
# 159346        1.293214      1399.25794834                     1425  1.317483
# 13940         0.786033      2712.60033163                     2627  0.766650
# 85826         0.786033      2712.60033163                     2627  0.771892
# 33248         1.096596      1429.96097536                     1461  1.149996
# 190799        1.096596      1429.96097536                     1461  1.156109
# 64796         0.774260       9.5156539252                        9  0.771892
# 96690         0.774260       9.5156539252                        9  0.766650
# 187107        0.766960    2561.1017916142                    20067  6.009655
# 193423        0.766960    2561.1017916142                     1954  0.585251
# 15320         1.000000             2592.0                     3380  1.304376
# 166362        1.000000             2592.0                     2592  1.000000
# 21482         1.603600  418941.1749558896                   427644  1.309950
# 25143         1.603600  418941.1749558896                   427644  1.317483
# 119055        1.156470        6036.775749                     6002  1.149996
# 191184        1.156470        6036.775749                     6002  1.149996
# 105159        1.000000             8698.0                     8698  1.000000
# 163626        1.000000             8734.0                     8734  1.000000
# 2973          1.000000            25766.0                    33608  1.304376
# 100227        1.000000            25766.0                    25766  1.000000
# 59526         1.000000            30062.0                    39212  1.304376
# 133960        1.000000            30062.0                    30062  1.000000
# 168921        1.412765       4690.3785052                     4793  1.317483
# 178641        1.412765       4690.3785052                     4793  1.309950
#
#         current_currency       usd_type  spotlight  creator_registered  \
# 10531                USD  international       True                True
# 69099                USD  international       True                True
# 184333               USD  international       True                True
# 204054               CAD           None       True                True
# 83960                USD  international      False                True
# 203854               USD  international      False                True
# 67679                USD  international       True                True
# 160239               CAD           None       True                True
# 84917                USD       domestic      False                True
# 105652               NZD           None      False                True
# 27985                USD  international       True                True
# 162084               CAD           None       True                True
# 64961                USD  international      False                True
# 121955               USD       domestic      False                True
# 171904               USD  international      False                True
# 205007               USD  international      False                True
# 72812                USD  international      False                True
# 106469               USD       domestic      False                True
# 52566                CAD           None       True                True
# 95609                USD  international       True                True
# 1030                 USD  international       True                True
# 83031                USD  international       True                True
# 40734                USD  international       True                True
# 191650               USD  international       True                True
# 105318               USD  international       True                True
# 160257               CAD           None       True                True
# 65687                USD       domestic      False                True
# 91937                USD  international      False                True
# 24068                USD  international       True                True
# 181754               USD  international       True                True
# ...                  ...            ...        ...                 ...
# 204157               USD       domestic      False                True
# 205551               USD  international      False                True
# 18192                CAD           None       True                True
# 198665               USD  international       True                True
# 29566                USD  international       True                True
# 179553               CAD           None       True                True
# 79533                USD  international      False                True
# 159346               USD  international      False                True
# 13940                USD  international       True                True
# 85826                USD  international       True                True
# 33248                USD  international       True                True
# 190799               USD  international       True                True
# 64796                USD  international      False                True
# 96690                USD  international      False                True
# 187107               HKD           None      False                True
# 193423               GBP           None      False                True
# 15320                CAD           None       True                True
# 166362               USD  international       True                True
# 21482                USD  international       True                True
# 25143                USD  international       True                True
# 119055               USD       domestic      False                True
# 191184               USD  international      False                True
# 105159               USD  international      False                True
# 163626               USD  international      False                True
# 2973                 CAD           None       True                True
# 100227               USD  international       True                True
# 59526                CAD           None       True                True
# 133960               USD  international       True                True
# 168921               USD  international       True                True
# 178641               USD  international       True                True
#
#              state
# 10531   successful
# 69099   successful
# 184333  successful
# 204054  successful
# 83960         live
# 203854        live
# 67679   successful
# 160239  successful
# 84917         live
# 105652        live
# 27985   successful
# 162084  successful
# 64961         live
# 121955        live
# 171904        live
# 205007        live
# 72812         live
# 106469        live
# 52566   successful
# 95609   successful
# 1030    successful
# 83031   successful
# 40734   successful
# 191650  successful
# 105318  successful
# 160257  successful
# 65687         live
# 91937         live
# 24068   successful
# 181754  successful
# ...            ...
# 204157        live
# 205551        live
# 18192   successful
# 198665  successful
# 29566   successful
# 179553  successful
# 79533         live
# 159346        live
# 13940   successful
# 85826   successful
# 33248   successful
# 190799  successful
# 64796         live
# 96690         live
# 187107        live
# 193423        live
# 15320   successful
# 166362  successful
# 21482   successful
# 25143   successful
# 119055        live
# 191184        live
# 105159        live
# 163626        live
# 2973    successful
# 100227  successful
# 59526   successful
# 133960  successful
# 168921  successful
# 178641  successful
#
# [4332 rows x 32 columns]

# %%
# It looks like some of the rows look different due to usd_pledged, converted_pledged_amount, fx_rate (which appears to be 
# exchange rate), and current_currency. Let's just delete the following currency-related columns:
# currency_symbol, static_usd_rate, convertd_pledged_amount, fx_rate, current_currency, usd_type
df.drop(columns=['currency_symbol','static_usd_rate','converted_pledged_amount','fx_rate','current_currency','usd_type'], 
        inplace=True)

# %%
df.shape
# Out:
# (189240, 26)

# %%
df.columns
# Out:
# Index(['id', 'name', 'blurb', 'category_name', 'category_slug',
#        'category_position', 'category_parent_id', 'goal', 'pledged',
#        'disable_communication', 'loc_country', 'loc_state', 'country',
#        'currency', 'currency_trailing_code', 'deadline', 'state_changed_at',
#        'created_at', 'launched_at', 'staff_pick', 'is_starrable',
#        'backers_count', 'usd_pledged', 'spotlight', 'creator_registered',
#        'state'],
#       dtype='object')

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (187367, 26)

# %%
# We dropped 189240-187367=1873 duplicate rows

# %%
# Search for more duplicates
len(df["id"].unique()) - len(df)
# Out:
# -293

# %%
# There are still 293 duplicate ID rows

# %%
# Explore the duplicate ID rows
pd.concat(g for _, g in df.groupby("id") if len(g) > 1)
# Out:
#                 id                                               name  \
# 83960      2705005  LOVE MEI waterproof case, protect iPhone X/Xs ...
# 203854     2705005  LOVE MEI waterproof case, protect iPhone X/Xs ...
# 171904     8412272  The ultimate music performance machine for stu...
# 205007     8412272  The ultimate music performance machine for stu...
# 65687     14064883  Wild Assent - Survive the Arena and Tame the W...
# 91937     14064883  Wild Assent - Survive the Arena and Tame the W...
# 14117     19007390                    Ballpoint Beauties by Frank Cho
# 62910     19007390                    Ballpoint Beauties by Frank Cho
# 113301    23895468       Campy Creatures: Expansion I and 2nd Edition
# 145655    23895468       Campy Creatures: Expansion I and 2nd Edition
# 197907    42520284                       Pretty Pins for Petty People
# 202815    42520284                       Pretty Pins for Petty People
# 127194    47521891                    Savage Worlds Adventure Edition
# 140015    47521891                    Savage Worlds Adventure Edition
# 144981    48018526  Camper Hooded Jacket 2.0 | Packable, Lightweig...
# 148822    48018526  Camper Hooded Jacket 2.0 | Packable, Lightweig...
# 64049     50131057   ENEMY WEAPON | A Card Game for Sexy Billionaires
# 158473    50131057   ENEMY WEAPON | A Card Game for Sexy Billionaires
# 23305     59430470             Sandy Petersen's Cthulhu Mythos for 5e
# 145710    59430470             Sandy Petersen's Cthulhu Mythos for 5e
# 119937    61874048  Nick Bounty and the Dame with the Blue Chewed ...
# 129967    61874048  Nick Bounty and the Dame with the Blue Chewed ...
# 40571     65454472                  Yooka-Laylee and the Kracklestone
# 174770    65454472                  Yooka-Laylee and the Kracklestone
# 85304     66753602                   JLP Live Featuring Madi & AliceX
# 163992    66753602                   JLP Live Featuring Madi & AliceX
# 22171     79015535  RPG Stamps: Commemorate Deaths and Track Accom...
# 25474     79015535  RPG Stamps: Commemorate Deaths and Track Accom...
# 56393     80991430                                  Stories for Being
# 126763    80991430                                  Stories for Being
# ...            ...                                                ...
# 1411    2027940022               ILL-LEGITIMATE: Operation -STITCHED-
# 205398  2027940022               ILL-LEGITIMATE: Operation -STITCHED-
# 61436   2030163004         Recuperando mis sueños y mi vida - cocinar
# 127302  2030163004         Recuperando mis sueños y mi vida - cocinar
# 19892   2034696525  Terror at 30,000 feet - A gamebook where YOU a...
# 77400   2034696525  Terror at 30,000 feet - A gamebook where YOU a...
# 9723    2048304930                                 Soulstice Bracelet
# 193857  2048304930                                 Soulstice Bracelet
# 100253  2055828829              Animal Companion Miniatures by Critit
# 183455  2055828829              Animal Companion Miniatures by Critit
# 97941   2058407205                                              JetDm
# 201832  2058407205                                              JetDm
# 31846   2075503828   X-POD™ | The Ultimate Evolution Of Compact Carry
# 60051   2075503828   X-POD™ | The Ultimate Evolution Of Compact Carry
# 130735  2082431965  Data Science Foundational Program - 4 Courses ...
# 184727  2082431965  Data Science Foundational Program - 4 Courses ...
# 78394   2091092566  TMG 10th Anniversary Edition Belfort with NEW ...
# 147727  2091092566  TMG 10th Anniversary Edition Belfort with NEW ...
# 97806   2107291434   Viviré : Solo quedas tu? Pelea para sobre vivir.
# 166705  2107291434   Viviré : Solo quedas tu? Pelea para sobre vivir.
# 91064   2116651522  Wallor 2.0 Isn't It Time You Demanded More Fro...
# 188886  2116651522  Wallor 2.0 Isn't It Time You Demanded More Fro...
# 17235   2118979587                  Xuan Wu: Starship Map & Miniature
# 112395  2118979587                  Xuan Wu: Starship Map & Miniature
# 73276   2127301698                     Rain: A Novel by Tim Antonides
# 203030  2127301698                     Rain: A Novel by Tim Antonides
# 39476   2129002837                  Ancient Terrible Things: AwakeTen
# 153692  2129002837                  Ancient Terrible Things: AwakeTen
# 105159  2144192426                                  THRESHOLD: ALLURE
# 163626  2144192426                                  THRESHOLD: ALLURE
#
#                                                     blurb     category_name  \
# 83960   This IP68 Waterproof Case for iPhone X/Xs, wit...           Gadgets
# 203854  This IP68 Waterproof Case for iPhone X/Xs, wit...           Gadgets
# 171904  Pipes is a new audio platform which out-horsep...          Hardware
# 205007  Pipes is a new audio platform which out-horsep...          Hardware
# 65687   A 1-4 player board game with solo/cooperative ...    Tabletop Games
# 91937   A 1-4 player board game with solo/cooperative ...    Tabletop Games
# 14117   This art book reveals Frank Cho’s ballpoint pe...         Art Books
# 62910   This art book reveals Frank Cho’s ballpoint pe...         Art Books
# 113301  This ghoulish game of bluffing and deduction j...    Tabletop Games
# 145655  This ghoulish game of bluffing and deduction j...    Tabletop Games
# 197907  Relatable enamel pins with a cute aesthetic an...       Accessories
# 202815  Relatable enamel pins with a cute aesthetic an...       Accessories
# 127194  The Savage Worlds game system from Pinnacle in...    Tabletop Games
# 140015  The Savage Worlds game system from Pinnacle in...    Tabletop Games
# 144981  A "Mountain to City"puffy jacket that's packab...    Product Design
# 148822  A "Mountain to City"puffy jacket that's packab...    Product Design
# 64049   Another one of those card-based party games wh...    Tabletop Games
# 158473  Another one of those card-based party games wh...    Tabletop Games
# 23305   The definitive guide by Sandy Petersen. New ru...    Tabletop Games
# 145710  The definitive guide by Sandy Petersen. New ru...    Tabletop Games
# 119937  A comedic noir adventure video game featuring ...       Video Games
# 129967  A comedic noir adventure video game featuring ...       Video Games
# 40571   A brand new graphic novel based on the charact...    Graphic Novels
# 174770  A brand new graphic novel based on the charact...    Graphic Novels
# 85304           Artistic photography, pinups and posters.            People
# 163992          Artistic photography, pinups and posters.            People
# 22171   R.I.P., Campaign, and Quest stamps for RPGs. D...    Tabletop Games
# 25474   R.I.P., Campaign, and Quest stamps for RPGs. D...    Tabletop Games
# 56393                    A mindful children's book series  Children's Books
# 126763                   A mindful children's book series  Children's Books
# ...                                                   ...               ...
# 1411    Help us create and launch our new project with...           Hip-Hop
# 205398  Help us create and launch our new project with...           Hip-Hop
# 61436   Crecer mi cocina, acondicionando un camión con...       Food Trucks
# 127302  Crecer mi cocina, acondicionando un camión con...       Food Trucks
# 19892                 A game book where YOU are the hero.    Tabletop Games
# 77400                 A game book where YOU are the hero.    Tabletop Games
# 9723    Earth inspired eco-bracelet that funds the pro...       Accessories
# 193857  Earth inspired eco-bracelet that funds the pro...       Accessories
# 100253  Animal Companion Miniatures for game play in b...    Tabletop Games
# 183455  Animal Companion Miniatures for game play in b...    Tabletop Games
# 97941   Je suis un manager artiste,qui vien d’ouvrir s...               Pop
# 201832  Je suis un manager artiste,qui vien d’ouvrir s...               Pop
# 31846   Designed as an extension of your pocket to car...    Product Design
# 60051   Designed as an extension of your pocket to car...    Product Design
# 130735  Data Science Foundational Program that incorpo...               Web
# 184727  Data Science Foundational Program that incorpo...               Web
# 78394   Belfort has been out of print too long - so no...    Tabletop Games
# 147727  Belfort has been out of print too long - so no...    Tabletop Games
# 97806   En un mudo donde todo fue arrasado por guerras...       Video Games
# 166705  En un mudo donde todo fue arrasado por guerras...       Video Games
# 91064   Wireless Phone Charging | Augmented Reality | ...    Product Design
# 188886  Wireless Phone Charging | Augmented Reality | ...    Product Design
# 17235   Starship miniature & poster map for Starfinder...    Tabletop Games
# 112395  Starship miniature & poster map for Starfinder...    Tabletop Games
# 73276   A full-length novel about a couple's desperate...           Fiction
# 203030  A full-length novel about a couple's desperate...           Fiction
# 39476   Celebrating 10 years since the conception of t...    Tabletop Games
# 153692  Celebrating 10 years since the conception of t...    Tabletop Games
# 105159             Threshold returns!  Introducing Praxi!       Comic Books
# 163626             Threshold returns!  Introducing Praxi!       Comic Books
#
#                       category_slug  category_position  category_parent_id  \
# 83960            technology/gadgets                  7                16.0
# 203854           technology/gadgets                  7                16.0
# 171904          technology/hardware                  8                16.0
# 205007          technology/hardware                  8                16.0
# 65687          games/tabletop games                  6                12.0
# 91937          games/tabletop games                  6                12.0
# 14117          publishing/art books                  3                18.0
# 62910          publishing/art books                  3                18.0
# 113301         games/tabletop games                  6                12.0
# 145655         games/tabletop games                  6                12.0
# 197907          fashion/accessories                  1                 9.0
# 202815          fashion/accessories                  1                 9.0
# 127194         games/tabletop games                  6                12.0
# 140015         games/tabletop games                  6                12.0
# 144981        design/product design                  5                 7.0
# 148822        design/product design                  5                 7.0
# 64049          games/tabletop games                  6                12.0
# 158473         games/tabletop games                  6                12.0
# 23305          games/tabletop games                  6                12.0
# 145710         games/tabletop games                  6                12.0
# 119937            games/video games                  7                12.0
# 129967            games/video games                  7                12.0
# 40571         comics/graphic novels                  4                 3.0
# 174770        comics/graphic novels                  4                 3.0
# 85304            photography/people                  4                15.0
# 163992           photography/people                  4                15.0
# 22171          games/tabletop games                  6                12.0
# 25474          games/tabletop games                  6                12.0
# 56393   publishing/children's books                  5                18.0
# 126763  publishing/children's books                  5                18.0
# ...                             ...                ...                 ...
# 1411                  music/hip-hop                  8                14.0
# 205398                music/hip-hop                  8                14.0
# 61436              food/food trucks                  8                10.0
# 127302             food/food trucks                  8                10.0
# 19892          games/tabletop games                  6                12.0
# 77400          games/tabletop games                  6                12.0
# 9723            fashion/accessories                  1                 9.0
# 193857          fashion/accessories                  1                 9.0
# 100253         games/tabletop games                  6                12.0
# 183455         games/tabletop games                  6                12.0
# 97941                     music/pop                 14                14.0
# 201832                    music/pop                 14                14.0
# 31846         design/product design                  5                 7.0
# 60051         design/product design                  5                 7.0
# 130735               technology/web                 15                16.0
# 184727               technology/web                 15                16.0
# 78394          games/tabletop games                  6                12.0
# 147727         games/tabletop games                  6                12.0
# 97806             games/video games                  7                12.0
# 166705            games/video games                  7                12.0
# 91064         design/product design                  5                 7.0
# 188886        design/product design                  5                 7.0
# 17235          games/tabletop games                  6                12.0
# 112395         games/tabletop games                  6                12.0
# 73276            publishing/fiction                  7                18.0
# 203030           publishing/fiction                  7                18.0
# 39476          games/tabletop games                  6                12.0
# 153692         games/tabletop games                  6                12.0
# 105159           comics/comic books                  2                 3.0
# 163626           comics/comic books                  2                 3.0
#
#             goal    pledged  disable_communication  ...   state_changed_at  \
# 83960    24000.0    1110.00                  False  ...         1537842973
# 203854   24000.0    1110.00                  False  ...         1537842973
# 171904  100000.0  106609.00                  False  ...         1539638486
# 205007  100000.0  107407.00                  False  ...         1539638486
# 65687    70000.0  253377.00                  False  ...         1539705669
# 91937    70000.0  254472.00                  False  ...         1539705669
# 14117    15000.0  108788.00                  False  ...         1539701149
# 62910    15000.0  108211.00                  False  ...         1539701149
# 113301   10000.0   57478.00                  False  ...         1539090014
# 145655   10000.0   57464.00                  False  ...         1539090014
# 197907     500.0   12082.00                  False  ...         1539125822
# 202815     500.0   11961.00                  False  ...         1539125822
# 127194   15000.0  216717.00                  False  ...         1539705721
# 140015   15000.0  217692.00                  False  ...         1539705721
# 144981   50000.0  271818.00                  False  ...         1537279320
# 148822   50000.0  271923.00                  False  ...         1537279320
# 64049    10000.0    3373.01                  False  ...         1539705098
# 158473   10000.0    3338.01                  False  ...         1539705098
# 23305    10000.0  181671.26                  False  ...         1538416777
# 145710   10000.0  181873.26                  False  ...         1538416777
# 119937   10000.0   13121.00                  False  ...         1538379123
# 129967   10000.0   13120.00                  False  ...         1538379123
# 40571    40000.0   18766.00                  False  ...         1539801058
# 174770   40000.0   18927.00                  False  ...         1539801058
# 85304      500.0     786.00                  False  ...         1537296271
# 163992     500.0     866.00                  False  ...         1537296271
# 22171     2000.0   17177.00                  False  ...         1537792187
# 25474     2000.0   17067.00                  False  ...         1537792187
# 56393    15000.0     691.00                  False  ...         1539788010
# 126763   15000.0     718.00                  False  ...         1539788010
# ...          ...        ...                    ...  ...                ...
# 1411      4000.0    9830.29                  False  ...         1537139027
# 205398    4000.0   10225.29                  False  ...         1537139027
# 61436   300000.0      18.80                  False  ...         1539315326
# 127302  300000.0      18.80                  False  ...         1539315326
# 19892      450.0     217.00                  False  ...         1539268783
# 77400      450.0     212.00                  False  ...         1539268783
# 9723     10000.0   16051.00                  False  ...         1537276160
# 193857   10000.0   15955.00                  False  ...         1537276160
# 100253   10000.0   38466.00                  False  ...         1538420402
# 183455   10000.0   38566.00                  False  ...         1538420402
# 97941     5000.0       1.29                  False  ...         1539744833
# 201832    5000.0       1.29                  False  ...         1539744833
# 31846    12000.0   25175.00                  False  ...         1538377202
# 60051    12000.0   25374.00                  False  ...         1538377202
# 130735    1000.0    1645.00                  False  ...         1539668614
# 184727    1000.0    1824.00                  False  ...         1539668614
# 78394    30000.0  126614.18                  False  ...         1538490836
# 147727   30000.0  126360.18                  False  ...         1538490836
# 97806   600000.0    1118.80                  False  ...         1539133784
# 166705  600000.0    1118.80                  False  ...         1539133784
# 91064    25000.0   52480.00                  False  ...         1539089006
# 188886   25000.0   52641.00                  False  ...         1539089006
# 17235     2500.0    3256.00                  False  ...         1539787722
# 112395    2500.0    3303.00                  False  ...         1539787722
# 73276    10000.0    8971.29                  False  ...         1538491086
# 203030   10000.0    8821.29                  False  ...         1538491086
# 39476     1000.0   49845.00                  False  ...         1539115476
# 153692    1000.0   49977.00                  False  ...         1539115476
# 105159    1800.0    8698.00                  False  ...         1539545546
# 163626    1800.0    8734.00                  False  ...         1539545546
#
#         created_at launched_at staff_pick  is_starrable  backers_count  \
# 83960   1534754716  1537842973      False          True             11
# 203854  1534754716  1537842973      False          True             11
# 171904  1537803552  1539638485       True          True            243
# 205007  1537803552  1539638485       True          True            245
# 65687   1535029742  1539705669      False          True           1612
# 91937   1535029742  1539705669      False          True           1619
# 14117   1537557822  1539701148      False          True           1454
# 62910   1537557822  1539701148      False          True           1441
# 113301  1537895307  1539090013      False          True           1988
# 145655  1537895307  1539090013      False          True           1989
# 197907  1536729103  1539125821      False          True            310
# 202815  1536729103  1539125821      False          True            308
# 127194  1531255843  1539705720      False          True           2098
# 140015  1531255843  1539705720      False          True           2110
# 144981  1532018098  1537279319      False          True           2195
# 148822  1532018098  1537279319      False          True           2196
# 64049   1526503052  1539705097      False          True             80
# 158473  1526503052  1539705097      False          True             79
# 23305   1534278952  1538416777       True          True           3273
# 145710  1534278952  1538416777       True          True           3277
# 119937  1537411489  1538379123       True          True            298
# 129967  1537411489  1538379123       True          True            297
# 40571   1534268519  1539801057      False          True            268
# 174770  1534268519  1539801057      False          True            270
# 85304   1537042516  1537296271      False         False             17
# 163992  1537042516  1537296271      False         False             18
# 22171   1523379368  1537792187       True         False            590
# 25474   1523379368  1537792187       True         False            586
# 56393   1536861221  1539788009      False          True             14
# 126763  1536861221  1539788009      False          True             15
# ...            ...         ...        ...           ...            ...
# 1411    1522859784  1537139027      False          True             78
# 205398  1522859784  1537139027      False          True             80
# 61436   1538449216  1539315325      False          True              1
# 127302  1538449216  1539315325      False          True              1
# 19892   1538830796  1539268782      False          True             19
# 77400   1538830796  1539268782      False          True             18
# 9723    1532572333  1537276160      False         False            316
# 193857  1532572333  1537276160      False         False            314
# 100253  1537213021  1538420402      False          True            883
# 183455  1537213021  1538420402      False          True            884
# 97941   1539740470  1539744833      False          True              1
# 201832  1539740470  1539744833      False          True              1
# 31846   1534030472  1538377201      False          True            155
# 60051   1534030472  1538377201      False          True            156
# 130735  1539174757  1539668613      False          True             43
# 184727  1539174757  1539668613      False          True             45
# 78394   1490383281  1538490836      False         False           2324
# 147727  1490383281  1538490836      False         False           2318
# 97806   1539116407  1539133784      False          True              3
# 166705  1539116407  1539133784      False          True              3
# 91064   1530531024  1539089005      False          True            354
# 188886  1530531024  1539089005      False          True            355
# 17235   1539714389  1539787722      False          True            101
# 112395  1539714389  1539787722      False          True            103
# 73276   1533154484  1538491085      False          True            116
# 203030  1533154484  1538491085      False          True            115
# 39476   1534762430  1539115476      False          True            974
# 153692  1534762430  1539115476      False          True            976
# 105159  1537754589  1539545545      False          True            115
# 163626  1537754589  1539545545      False          True            117
#
#             usd_pledged  spotlight  creator_registered  state
# 83960       142.1373093      False                True   live
# 203854      142.0867266      False                True   live
# 171904         106609.0      False                True   live
# 205007         107407.0      False                True   live
# 65687          253377.0      False                True   live
# 91937          254472.0      False                True   live
# 14117          108788.0      False                True   live
# 62910          108211.0      False                True   live
# 113301          57478.0      False                True   live
# 145655          57464.0      False                True   live
# 197907          12082.0      False                True   live
# 202815          11961.0      False                True   live
# 127194         216717.0      False                True   live
# 140015         217692.0      False                True   live
# 144981         271818.0      False                True   live
# 148822         271923.0      False                True   live
# 64049           3373.01      False                True   live
# 158473          3338.01      False                True   live
# 23305         181671.26      False                True   live
# 145710        181873.26      False                True   live
# 119937          13121.0      False                True   live
# 129967          13120.0      False                True   live
# 40571           18766.0      False                True   live
# 174770          18927.0      False                True   live
# 85304             786.0      False                True   live
# 163992            866.0      False                True   live
# 22171           17177.0      False                True   live
# 25474           17067.0      False                True   live
# 56393             691.0      False                True   live
# 126763            718.0      False                True   live
# ...                 ...        ...                 ...    ...
# 1411    7538.8492043942      False                True   live
# 205398  7841.7746964942      False                True   live
# 61436       0.988622628      False                True   live
# 127302      0.980620972      False                True   live
# 19892      249.77669773      False                True   live
# 77400      244.02147428      False                True   live
# 9723            16051.0      False                True   live
# 193857          15955.0      False                True   live
# 100253   50125.09768308      False                True   live
# 183455   50255.40782108      False                True   live
# 97941      0.9903863415      False                True   live
# 201832     0.9928476486      False                True   live
# 31846           25175.0      False                True   live
# 60051           25374.0      False                True   live
# 130735           1645.0      False                True   live
# 184727           1824.0      False                True   live
# 78394         126614.18      False                True   live
# 147727        126360.18      False                True   live
# 97806       59.55545814      False                True   live
# 166705      59.04176112      False                True   live
# 91064           52480.0      False                True   live
# 188886          52641.0      False                True   live
# 17235            3256.0      False                True   live
# 112395           3303.0      False                True   live
# 73276    6989.168701755      False                True   live
# 203030   6872.309776755      False                True   live
# 39476           49845.0      False                True   live
# 153692          49977.0      False                True   live
# 105159           8698.0      False                True   live
# 163626           8734.0      False                True   live
#
# [586 rows x 26 columns]

# %%
pd.options.display.max_columns = None

# %%
df.loc[[171904,205007]]
# Out:
#              id                                               name  \
# 171904  8412272  The ultimate music performance machine for stu...
# 205007  8412272  The ultimate music performance machine for stu...
#
#                                                     blurb category_name  \
# 171904  Pipes is a new audio platform which out-horsep...      Hardware
# 205007  Pipes is a new audio platform which out-horsep...      Hardware
#
#               category_slug  category_position  category_parent_id      goal  \
# 171904  technology/hardware                  8                16.0  100000.0
# 205007  technology/hardware                  8                16.0  100000.0
#
#          pledged  disable_communication loc_country loc_state country  \
# 171904  106609.0                  False          US        CA      US
# 205007  107407.0                  False          US        CA      US
#
#        currency  currency_trailing_code    deadline  state_changed_at  \
# 171904      USD                    True  1542234085        1539638486
# 205007      USD                    True  1542234085        1539638486
#
#         created_at  launched_at  staff_pick  is_starrable  backers_count  \
# 171904  1537803552   1539638485        True          True            243
# 205007  1537803552   1539638485        True          True            245
#
#        usd_pledged  spotlight  creator_registered state
# 171904    106609.0      False                True  live
# 205007    107407.0      False                True  live

# %%
# It looks like there are differences with pledged, backers_count and usd_pledged

# %%
# usd_pledged is redundant with pledged - remove usd_pledged
df.drop(columns=['usd_pledged'], inplace=True)

# %%
df.shape
# Out:
# (187367, 25)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (187345, 25)

# %%
# we dropped 187367-187345=22 duplicate rows

# %%
# Search for more duplicates
len(df["id"].unique()) - len(df)
# Out:
# -271

# %%
# There are still 271 duplicates

# %%
# is_starrable is unclear and seems to be a problem with duplicates. Let's drop it
df.drop(columns=['is_starrable'], inplace=True)

# %%
df.shape
# Out:
# (187345, 24)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (187344, 24)

# %%
# Search for more duplicates
len(df["id"].unique()) - len(df)
# Out:
# -270

# %%
# There are still 270 duplicates

# %%
df.loc[[171904,205007]]
# Out:
#              id                                               name  \
# 171904  8412272  The ultimate music performance machine for stu...
# 205007  8412272  The ultimate music performance machine for stu...
#
#                                                     blurb category_name  \
# 171904  Pipes is a new audio platform which out-horsep...      Hardware
# 205007  Pipes is a new audio platform which out-horsep...      Hardware
#
#               category_slug  category_position  category_parent_id      goal  \
# 171904  technology/hardware                  8                16.0  100000.0
# 205007  technology/hardware                  8                16.0  100000.0
#
#          pledged  disable_communication loc_country loc_state country  \
# 171904  106609.0                  False          US        CA      US
# 205007  107407.0                  False          US        CA      US
#
#        currency  currency_trailing_code    deadline  state_changed_at  \
# 171904      USD                    True  1542234085        1539638486
# 205007      USD                    True  1542234085        1539638486
#
#         created_at  launched_at  staff_pick  backers_count  spotlight  \
# 171904  1537803552   1539638485        True            243      False
# 205007  1537803552   1539638485        True            245      False
#
#         creator_registered state
# 171904                True  live
# 205007                True  live

# %%
# Still differences between pledged and backers_count. Without some sort of a time stamp we don't know which one is the most
# updated row. Let's look for duplicate IDs, then keep the rows with the largest pledge values
df_duplicates = pd.concat(g for _, g in df.groupby("id") if len(g) > 1)

# %%
df_duplicates
# Out:
#                 id                                               name  \
# 171904     8412272  The ultimate music performance machine for stu...
# 205007     8412272  The ultimate music performance machine for stu...
# 65687     14064883  Wild Assent - Survive the Arena and Tame the W...
# 91937     14064883  Wild Assent - Survive the Arena and Tame the W...
# 14117     19007390                    Ballpoint Beauties by Frank Cho
# 62910     19007390                    Ballpoint Beauties by Frank Cho
# 113301    23895468       Campy Creatures: Expansion I and 2nd Edition
# 145655    23895468       Campy Creatures: Expansion I and 2nd Edition
# 197907    42520284                       Pretty Pins for Petty People
# 202815    42520284                       Pretty Pins for Petty People
# 127194    47521891                    Savage Worlds Adventure Edition
# 140015    47521891                    Savage Worlds Adventure Edition
# 144981    48018526  Camper Hooded Jacket 2.0 | Packable, Lightweig...
# 148822    48018526  Camper Hooded Jacket 2.0 | Packable, Lightweig...
# 64049     50131057   ENEMY WEAPON | A Card Game for Sexy Billionaires
# 158473    50131057   ENEMY WEAPON | A Card Game for Sexy Billionaires
# 23305     59430470             Sandy Petersen's Cthulhu Mythos for 5e
# 145710    59430470             Sandy Petersen's Cthulhu Mythos for 5e
# 119937    61874048  Nick Bounty and the Dame with the Blue Chewed ...
# 129967    61874048  Nick Bounty and the Dame with the Blue Chewed ...
# 40571     65454472                  Yooka-Laylee and the Kracklestone
# 174770    65454472                  Yooka-Laylee and the Kracklestone
# 85304     66753602                   JLP Live Featuring Madi & AliceX
# 163992    66753602                   JLP Live Featuring Madi & AliceX
# 22171     79015535  RPG Stamps: Commemorate Deaths and Track Accom...
# 25474     79015535  RPG Stamps: Commemorate Deaths and Track Accom...
# 56393     80991430                                  Stories for Being
# 126763    80991430                                  Stories for Being
# 63942     83261365                                 Hagglethorn Hollow
# 131736    83261365                                 Hagglethorn Hollow
# ...            ...                                                ...
# 19804   1984036706                       Mirage Deck of Playing Cards
# 53250   1984036706                       Mirage Deck of Playing Cards
# 27697   1989292659             Black Sailors: Legends of the Jade Sea
# 94983   1989292659             Black Sailors: Legends of the Jade Sea
# 159399  2000626596                                         Spellbound
# 201931  2000626596                                         Spellbound
# 1411    2027940022               ILL-LEGITIMATE: Operation -STITCHED-
# 205398  2027940022               ILL-LEGITIMATE: Operation -STITCHED-
# 19892   2034696525  Terror at 30,000 feet - A gamebook where YOU a...
# 77400   2034696525  Terror at 30,000 feet - A gamebook where YOU a...
# 9723    2048304930                                 Soulstice Bracelet
# 193857  2048304930                                 Soulstice Bracelet
# 100253  2055828829              Animal Companion Miniatures by Critit
# 183455  2055828829              Animal Companion Miniatures by Critit
# 31846   2075503828   X-POD™ | The Ultimate Evolution Of Compact Carry
# 60051   2075503828   X-POD™ | The Ultimate Evolution Of Compact Carry
# 130735  2082431965  Data Science Foundational Program - 4 Courses ...
# 184727  2082431965  Data Science Foundational Program - 4 Courses ...
# 78394   2091092566  TMG 10th Anniversary Edition Belfort with NEW ...
# 147727  2091092566  TMG 10th Anniversary Edition Belfort with NEW ...
# 91064   2116651522  Wallor 2.0 Isn't It Time You Demanded More Fro...
# 188886  2116651522  Wallor 2.0 Isn't It Time You Demanded More Fro...
# 17235   2118979587                  Xuan Wu: Starship Map & Miniature
# 112395  2118979587                  Xuan Wu: Starship Map & Miniature
# 73276   2127301698                     Rain: A Novel by Tim Antonides
# 203030  2127301698                     Rain: A Novel by Tim Antonides
# 39476   2129002837                  Ancient Terrible Things: AwakeTen
# 153692  2129002837                  Ancient Terrible Things: AwakeTen
# 105159  2144192426                                  THRESHOLD: ALLURE
# 163626  2144192426                                  THRESHOLD: ALLURE
#
#                                                     blurb     category_name  \
# 171904  Pipes is a new audio platform which out-horsep...          Hardware
# 205007  Pipes is a new audio platform which out-horsep...          Hardware
# 65687   A 1-4 player board game with solo/cooperative ...    Tabletop Games
# 91937   A 1-4 player board game with solo/cooperative ...    Tabletop Games
# 14117   This art book reveals Frank Cho’s ballpoint pe...         Art Books
# 62910   This art book reveals Frank Cho’s ballpoint pe...         Art Books
# 113301  This ghoulish game of bluffing and deduction j...    Tabletop Games
# 145655  This ghoulish game of bluffing and deduction j...    Tabletop Games
# 197907  Relatable enamel pins with a cute aesthetic an...       Accessories
# 202815  Relatable enamel pins with a cute aesthetic an...       Accessories
# 127194  The Savage Worlds game system from Pinnacle in...    Tabletop Games
# 140015  The Savage Worlds game system from Pinnacle in...    Tabletop Games
# 144981  A "Mountain to City"puffy jacket that's packab...    Product Design
# 148822  A "Mountain to City"puffy jacket that's packab...    Product Design
# 64049   Another one of those card-based party games wh...    Tabletop Games
# 158473  Another one of those card-based party games wh...    Tabletop Games
# 23305   The definitive guide by Sandy Petersen. New ru...    Tabletop Games
# 145710  The definitive guide by Sandy Petersen. New ru...    Tabletop Games
# 119937  A comedic noir adventure video game featuring ...       Video Games
# 129967  A comedic noir adventure video game featuring ...       Video Games
# 40571   A brand new graphic novel based on the charact...    Graphic Novels
# 174770  A brand new graphic novel based on the charact...    Graphic Novels
# 85304           Artistic photography, pinups and posters.            People
# 163992          Artistic photography, pinups and posters.            People
# 22171   R.I.P., Campaign, and Quest stamps for RPGs. D...    Tabletop Games
# 25474   R.I.P., Campaign, and Quest stamps for RPGs. D...    Tabletop Games
# 56393                    A mindful children's book series  Children's Books
# 126763                   A mindful children's book series  Children's Books
# 63942   Hand-sculpted, highly detailed gaming scenery ...    Tabletop Games
# 131736  Hand-sculpted, highly detailed gaming scenery ...    Tabletop Games
# ...                                                   ...               ...
# 19804                  Oriental Illustrated Playing Cards     Playing Cards
# 53250                  Oriental Illustrated Playing Cards     Playing Cards
# 27697   High quality, 75mm resin miniatures for painte...    Tabletop Games
# 94983   High quality, 75mm resin miniatures for painte...    Tabletop Games
# 159399  Help bring the first volume of SPELLBOUND to p...    Graphic Novels
# 201931  Help bring the first volume of SPELLBOUND to p...    Graphic Novels
# 1411    Help us create and launch our new project with...           Hip-Hop
# 205398  Help us create and launch our new project with...           Hip-Hop
# 19892                 A game book where YOU are the hero.    Tabletop Games
# 77400                 A game book where YOU are the hero.    Tabletop Games
# 9723    Earth inspired eco-bracelet that funds the pro...       Accessories
# 193857  Earth inspired eco-bracelet that funds the pro...       Accessories
# 100253  Animal Companion Miniatures for game play in b...    Tabletop Games
# 183455  Animal Companion Miniatures for game play in b...    Tabletop Games
# 31846   Designed as an extension of your pocket to car...    Product Design
# 60051   Designed as an extension of your pocket to car...    Product Design
# 130735  Data Science Foundational Program that incorpo...               Web
# 184727  Data Science Foundational Program that incorpo...               Web
# 78394   Belfort has been out of print too long - so no...    Tabletop Games
# 147727  Belfort has been out of print too long - so no...    Tabletop Games
# 91064   Wireless Phone Charging | Augmented Reality | ...    Product Design
# 188886  Wireless Phone Charging | Augmented Reality | ...    Product Design
# 17235   Starship miniature & poster map for Starfinder...    Tabletop Games
# 112395  Starship miniature & poster map for Starfinder...    Tabletop Games
# 73276   A full-length novel about a couple's desperate...           Fiction
# 203030  A full-length novel about a couple's desperate...           Fiction
# 39476   Celebrating 10 years since the conception of t...    Tabletop Games
# 153692  Celebrating 10 years since the conception of t...    Tabletop Games
# 105159             Threshold returns!  Introducing Praxi!       Comic Books
# 163626             Threshold returns!  Introducing Praxi!       Comic Books
#
#                       category_slug  category_position  category_parent_id  \
# 171904          technology/hardware                  8                16.0
# 205007          technology/hardware                  8                16.0
# 65687          games/tabletop games                  6                12.0
# 91937          games/tabletop games                  6                12.0
# 14117          publishing/art books                  3                18.0
# 62910          publishing/art books                  3                18.0
# 113301         games/tabletop games                  6                12.0
# 145655         games/tabletop games                  6                12.0
# 197907          fashion/accessories                  1                 9.0
# 202815          fashion/accessories                  1                 9.0
# 127194         games/tabletop games                  6                12.0
# 140015         games/tabletop games                  6                12.0
# 144981        design/product design                  5                 7.0
# 148822        design/product design                  5                 7.0
# 64049          games/tabletop games                  6                12.0
# 158473         games/tabletop games                  6                12.0
# 23305          games/tabletop games                  6                12.0
# 145710         games/tabletop games                  6                12.0
# 119937            games/video games                  7                12.0
# 129967            games/video games                  7                12.0
# 40571         comics/graphic novels                  4                 3.0
# 174770        comics/graphic novels                  4                 3.0
# 85304            photography/people                  4                15.0
# 163992           photography/people                  4                15.0
# 22171          games/tabletop games                  6                12.0
# 25474          games/tabletop games                  6                12.0
# 56393   publishing/children's books                  5                18.0
# 126763  publishing/children's books                  5                18.0
# 63942          games/tabletop games                  6                12.0
# 131736         games/tabletop games                  6                12.0
# ...                             ...                ...                 ...
# 19804           games/playing cards                  4                12.0
# 53250           games/playing cards                  4                12.0
# 27697          games/tabletop games                  6                12.0
# 94983          games/tabletop games                  6                12.0
# 159399        comics/graphic novels                  4                 3.0
# 201931        comics/graphic novels                  4                 3.0
# 1411                  music/hip-hop                  8                14.0
# 205398                music/hip-hop                  8                14.0
# 19892          games/tabletop games                  6                12.0
# 77400          games/tabletop games                  6                12.0
# 9723            fashion/accessories                  1                 9.0
# 193857          fashion/accessories                  1                 9.0
# 100253         games/tabletop games                  6                12.0
# 183455         games/tabletop games                  6                12.0
# 31846         design/product design                  5                 7.0
# 60051         design/product design                  5                 7.0
# 130735               technology/web                 15                16.0
# 184727               technology/web                 15                16.0
# 78394          games/tabletop games                  6                12.0
# 147727         games/tabletop games                  6                12.0
# 91064         design/product design                  5                 7.0
# 188886        design/product design                  5                 7.0
# 17235          games/tabletop games                  6                12.0
# 112395         games/tabletop games                  6                12.0
# 73276            publishing/fiction                  7                18.0
# 203030           publishing/fiction                  7                18.0
# 39476          games/tabletop games                  6                12.0
# 153692         games/tabletop games                  6                12.0
# 105159           comics/comic books                  2                 3.0
# 163626           comics/comic books                  2                 3.0
#
#             goal    pledged  disable_communication loc_country     loc_state  \
# 171904  100000.0  106609.00                  False          US            CA
# 205007  100000.0  107407.00                  False          US            CA
# 65687    70000.0  253377.00                  False          US            VA
# 91937    70000.0  254472.00                  False          US            VA
# 14117    15000.0  108788.00                  False          US            CA
# 62910    15000.0  108211.00                  False          US            CA
# 113301   10000.0   57478.00                  False          US            GA
# 145655   10000.0   57464.00                  False          US            GA
# 197907     500.0   12082.00                  False          US            WA
# 202815     500.0   11961.00                  False          US            WA
# 127194   15000.0  216717.00                  False          US            AZ
# 140015   15000.0  217692.00                  False          US            AZ
# 144981   50000.0  271818.00                  False          US            UT
# 148822   50000.0  271923.00                  False          US            UT
# 64049    10000.0    3373.01                  False          US            CA
# 158473   10000.0    3338.01                  False          US            CA
# 23305    10000.0  181671.26                  False          US            TX
# 145710   10000.0  181873.26                  False          US            TX
# 119937   10000.0   13121.00                  False          US            CA
# 129967   10000.0   13120.00                  False          US            CA
# 40571    40000.0   18766.00                  False          US            NY
# 174770   40000.0   18927.00                  False          US            NY
# 85304      500.0     786.00                  False          US            TX
# 163992     500.0     866.00                  False          US            TX
# 22171     2000.0   17177.00                  False          US            CA
# 25474     2000.0   17067.00                  False          US            CA
# 56393    15000.0     691.00                  False          US            NY
# 126763   15000.0     718.00                  False          US            NY
# 63942    60000.0  394793.92                  False          NZ    Wellington
# 131736   60000.0  393261.92                  False          NZ    Wellington
# ...          ...        ...                    ...         ...           ...
# 19804     2000.0    4244.00                  False          US            NY
# 53250     2000.0    4189.00                  False          US            NY
# 27697    15000.0   32557.50                  False          ES        Madrid
# 94983    15000.0   32706.50                  False          ES        Madrid
# 159399   10000.0    4328.00                  False          US            OR
# 201931   10000.0    4038.00                  False          US            OR
# 1411      4000.0    9830.29                  False          CA            BC
# 205398    4000.0   10225.29                  False          CA            BC
# 19892      450.0     217.00                  False          FR        Centre
# 77400      450.0     212.00                  False          FR        Centre
# 9723     10000.0   16051.00                  False          US            CA
# 193857   10000.0   15955.00                  False          US            CA
# 100253   10000.0   38466.00                  False          GB       England
# 183455   10000.0   38566.00                  False          GB       England
# 31846    12000.0   25175.00                  False          US            CA
# 60051    12000.0   25374.00                  False          US            CA
# 130735    1000.0    1645.00                  False          US            FL
# 184727    1000.0    1824.00                  False          US            FL
# 78394    30000.0  126614.18                  False          US            UT
# 147727   30000.0  126360.18                  False          US            UT
# 91064    25000.0   52480.00                  False          US            NY
# 188886   25000.0   52641.00                  False          US            NY
# 17235     2500.0    3256.00                  False          US            PA
# 112395    2500.0    3303.00                  False          US            PA
# 73276    10000.0    8971.29                  False          CA            BC
# 203030   10000.0    8821.29                  False          CA            BC
# 39476     1000.0   49845.00                  False          ZA  Western Cape
# 153692    1000.0   49977.00                  False          ZA  Western Cape
# 105159    1800.0    8698.00                  False          US            IL
# 163626    1800.0    8734.00                  False          US            IL
#
#        country currency  currency_trailing_code    deadline  state_changed_at  \
# 171904      US      USD                    True  1542234085        1539638486
# 205007      US      USD                    True  1542234085        1539638486
# 65687       US      USD                    True  1540915269        1539705669
# 91937       US      USD                    True  1540915269        1539705669
# 14117       US      USD                    True  1542340800        1539701149
# 62910       US      USD                    True  1542340800        1539701149
# 113301      US      USD                    True  1541289600        1539090014
# 145655      US      USD                    True  1541289600        1539090014
# 197907      US      USD                    True  1541721421        1539125822
# 202815      US      USD                    True  1541721421        1539125822
# 127194      US      USD                    True  1542250800        1539705721
# 140015      US      USD                    True  1542250800        1539705721
# 144981      US      USD                    True  1541487540        1537279320
# 148822      US      USD                    True  1541487540        1537279320
# 64049       US      USD                    True  1542732697        1539705098
# 158473      US      USD                    True  1542732697        1539705098
# 23305       US      USD                    True  1540249200        1538416777
# 145710      US      USD                    True  1540249200        1538416777
# 119937      US      USD                    True  1540971123        1538379123
# 129967      US      USD                    True  1540971123        1538379123
# 40571       US      USD                    True  1542396657        1539801058
# 174770      US      USD                    True  1542396657        1539801058
# 85304       US      USD                    True  1539888271        1537296271
# 163992      US      USD                    True  1539888271        1537296271
# 22171       US      USD                    True  1539865787        1537792187
# 25474       US      USD                    True  1539865787        1537792187
# 56393       US      USD                    True  1542383609        1539788010
# 126763      US      USD                    True  1542383609        1539788010
# 63942       NZ      NZD                    True  1540515600        1537963249
# 131736      NZ      NZD                    True  1540515600        1537963249
# ...        ...      ...                     ...         ...               ...
# 19804       US      USD                    True  1541782800        1539663280
# 53250       US      USD                    True  1541782800        1539663280
# 27697       ES      EUR                   False  1540404000        1538676528
# 94983       ES      EUR                   False  1540404000        1538676528
# 159399      US      USD                    True  1542344400        1539814945
# 201931      US      USD                    True  1542344400        1539814945
# 1411        CA      CAD                    True  1540018740        1537139027
# 205398      CA      CAD                    True  1540018740        1537139027
# 19892       FR      EUR                   False  1541864382        1539268783
# 77400       FR      EUR                   False  1541864382        1539268783
# 9723        US      USD                    True  1539868160        1537276160
# 193857      US      USD                    True  1539868160        1537276160
# 100253      GB      GBP                   False  1540944000        1538420402
# 183455      GB      GBP                   False  1540944000        1538420402
# 31846       US      USD                    True  1542095940        1538377202
# 60051       US      USD                    True  1542095940        1538377202
# 130735      US      USD                    True  1543387020        1539668614
# 184727      US      USD                    True  1543387020        1539668614
# 78394       US      USD                    True  1540004400        1538490836
# 147727      US      USD                    True  1540004400        1538490836
# 91064       US      USD                    True  1542864120        1539089006
# 188886      US      USD                    True  1542864120        1539089006
# 17235       US      USD                    True  1541738700        1539787722
# 112395      US      USD                    True  1541738700        1539787722
# 73276       CA      CAD                    True  1541044740        1538491086
# 203030      CA      CAD                    True  1541044740        1538491086
# 39476       US      USD                    True  1540325076        1539115476
# 153692      US      USD                    True  1540325076        1539115476
# 105159      US      USD                    True  1540602000        1539545546
# 163626      US      USD                    True  1540602000        1539545546
#
#         created_at  launched_at  staff_pick  backers_count  spotlight  \
# 171904  1537803552   1539638485        True            243      False
# 205007  1537803552   1539638485        True            245      False
# 65687   1535029742   1539705669       False           1612      False
# 91937   1535029742   1539705669       False           1619      False
# 14117   1537557822   1539701148       False           1454      False
# 62910   1537557822   1539701148       False           1441      False
# 113301  1537895307   1539090013       False           1988      False
# 145655  1537895307   1539090013       False           1989      False
# 197907  1536729103   1539125821       False            310      False
# 202815  1536729103   1539125821       False            308      False
# 127194  1531255843   1539705720       False           2098      False
# 140015  1531255843   1539705720       False           2110      False
# 144981  1532018098   1537279319       False           2195      False
# 148822  1532018098   1537279319       False           2196      False
# 64049   1526503052   1539705097       False             80      False
# 158473  1526503052   1539705097       False             79      False
# 23305   1534278952   1538416777        True           3273      False
# 145710  1534278952   1538416777        True           3277      False
# 119937  1537411489   1538379123        True            298      False
# 129967  1537411489   1538379123        True            297      False
# 40571   1534268519   1539801057       False            268      False
# 174770  1534268519   1539801057       False            270      False
# 85304   1537042516   1537296271       False             17      False
# 163992  1537042516   1537296271       False             18      False
# 22171   1523379368   1537792187        True            590      False
# 25474   1523379368   1537792187        True            586      False
# 56393   1536861221   1539788009       False             14      False
# 126763  1536861221   1539788009       False             15      False
# 63942   1535515505   1537963248        True            657      False
# 131736  1535515505   1537963248        True            655      False
# ...            ...          ...         ...            ...        ...
# 19804   1538750214   1539663278       False             98      False
# 53250   1538750214   1539663278       False             97      False
# 27697   1537994412   1538676527        True            221      False
# 94983   1537994412   1538676527        True            222      False
# 159399  1539649027   1539814944       False             79      False
# 201931  1539649027   1539814944       False             73      False
# 1411    1522859784   1537139027       False             78      False
# 205398  1522859784   1537139027       False             80      False
# 19892   1538830796   1539268782       False             19      False
# 77400   1538830796   1539268782       False             18      False
# 9723    1532572333   1537276160       False            316      False
# 193857  1532572333   1537276160       False            314      False
# 100253  1537213021   1538420402       False            883      False
# 183455  1537213021   1538420402       False            884      False
# 31846   1534030472   1538377201       False            155      False
# 60051   1534030472   1538377201       False            156      False
# 130735  1539174757   1539668613       False             43      False
# 184727  1539174757   1539668613       False             45      False
# 78394   1490383281   1538490836       False           2324      False
# 147727  1490383281   1538490836       False           2318      False
# 91064   1530531024   1539089005       False            354      False
# 188886  1530531024   1539089005       False            355      False
# 17235   1539714389   1539787722       False            101      False
# 112395  1539714389   1539787722       False            103      False
# 73276   1533154484   1538491085       False            116      False
# 203030  1533154484   1538491085       False            115      False
# 39476   1534762430   1539115476       False            974      False
# 153692  1534762430   1539115476       False            976      False
# 105159  1537754589   1539545545       False            115      False
# 163626  1537754589   1539545545       False            117      False
#
#         creator_registered state
# 171904                True  live
# 205007                True  live
# 65687                 True  live
# 91937                 True  live
# 14117                 True  live
# 62910                 True  live
# 113301                True  live
# 145655                True  live
# 197907                True  live
# 202815                True  live
# 127194                True  live
# 140015                True  live
# 144981                True  live
# 148822                True  live
# 64049                 True  live
# 158473                True  live
# 23305                 True  live
# 145710                True  live
# 119937                True  live
# 129967                True  live
# 40571                 True  live
# 174770                True  live
# 85304                 True  live
# 163992                True  live
# 22171                 True  live
# 25474                 True  live
# 56393                 True  live
# 126763                True  live
# 63942                 True  live
# 131736                True  live
# ...                    ...   ...
# 19804                 True  live
# 53250                 True  live
# 27697                 True  live
# 94983                 True  live
# 159399                True  live
# 201931                True  live
# 1411                  True  live
# 205398                True  live
# 19892                 True  live
# 77400                 True  live
# 9723                  True  live
# 193857                True  live
# 100253                True  live
# 183455                True  live
# 31846                 True  live
# 60051                 True  live
# 130735                True  live
# 184727                True  live
# 78394                 True  live
# 147727                True  live
# 91064                 True  live
# 188886                True  live
# 17235                 True  live
# 112395                True  live
# 73276                 True  live
# 203030                True  live
# 39476                 True  live
# 153692                True  live
# 105159                True  live
# 163626                True  live
#
# [540 rows x 24 columns]

# %%
df = df.sort_values('pledged', ascending=False).drop_duplicates('id').sort_index()

# %%
df.loc[df["id"] == 8412272].pledged
# Out:
# 205007    107407.0
# Name: pledged, dtype: float64

# %%
# Looks like it worked!

# %%
# Search for more duplicates
len(df["id"].unique()) - len(df)
# Out:
# 0

# %%
df.shape
# Out:
# (187074, 24)

# %%
df.columns
# Out:
# Index(['id', 'name', 'blurb', 'category_name', 'category_slug',
#        'category_position', 'category_parent_id', 'goal', 'pledged',
#        'disable_communication', 'loc_country', 'loc_state', 'country',
#        'currency', 'currency_trailing_code', 'deadline', 'state_changed_at',
#        'created_at', 'launched_at', 'staff_pick', 'backers_count', 'spotlight',
#        'creator_registered', 'state'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187074 entries, 0 to 205695
# Data columns (total 24 columns):
# id                        187074 non-null int64
# name                      187074 non-null object
# blurb                     187074 non-null object
# category_name             187074 non-null object
# category_slug             187074 non-null object
# category_position         187074 non-null int64
# category_parent_id        169696 non-null float64
# goal                      187074 non-null float64
# pledged                   187074 non-null float64
# disable_communication     187074 non-null bool
# loc_country               186198 non-null object
# loc_state                 186155 non-null object
# country                   187074 non-null object
# currency                  187074 non-null object
# currency_trailing_code    187074 non-null bool
# deadline                  187074 non-null int64
# state_changed_at          187074 non-null int64
# created_at                187074 non-null int64
# launched_at               187074 non-null int64
# staff_pick                187074 non-null bool
# backers_count             187074 non-null int64
# spotlight                 187074 non-null bool
# creator_registered        187074 non-null bool
# state                     187074 non-null object
# dtypes: bool(5), float64(3), int64(7), object(9)
# memory usage: 29.4+ MB

# %%
# ---- FURTHER REFINE VARIABLES ----

# %%
df.head(3)
# Out:
#            id                                               name  \
# 0   895922629                       Jozii-College Jobs Made Easy
# 1  1190376005  DROPSY: A different take on the old school adv...
# 2   672906219  Letra Chueca / Crooked Letter: a printshop & b...
#
#                                                blurb category_name  \
# 0  Jozii is the premier service for full-time uni...           Web
# 1  Dropsy is an adventure game with a focus on ex...   Video Games
# 2  We've bought a press and already found a studi...   Letterpress
#
#             category_slug  category_position  category_parent_id    goal  \
# 0          technology/web                 15                16.0  3500.0
# 1       games/video games                  7                12.0   225.0
# 2  publishing/letterpress                  7                18.0  6500.0
#
#    pledged  disable_communication loc_country loc_state country currency  \
# 0    50.00                  False          US        NY      US      USD
# 1  1613.47                  False          US        FL      US      USD
# 2  6633.00                  False          US        OR      US      USD
#
#    currency_trailing_code    deadline  state_changed_at  created_at  \
# 0                    True  1417150740        1417150742  1413476386
# 1                    True  1320259151        1320259153  1317217452
# 2                    True  1410502338        1410502338  1403324529
#
#    launched_at  staff_pick  backers_count  spotlight  creator_registered  \
# 0   1414525374       False              1      False                True
# 1   1318876751        True             63       True                True
# 2   1407910338       False            113       True                True
#
#         state
# 0      failed
# 1  successful
# 2  successful

# %%
df.sort_values(by='category_parent_id')
# Out:
#                 id                                               name  \
# 178671   216696001      Ascending Angles For Love and Peace Awareness
# 100894  1200534677  Acrylic Charms: Confection Creatures, Good Luc...
# 28743   1529501840  ASHES , The dark drawings of Steven Russell Black
# 100896  1605679216                   Christmas Movie Pins: Home Alone
# 169239   910037537                 Is This LOSS? Meme Gold Enamel Pin
# 100902   682815690                      Study Abroad for Art in Italy
# 28734    894890621    Navajo Summer Arts Camp and Performance Program
# 169238  1408228827                                  Historical Museum
# 28730   1166987622  Arizona Between Nosotros: Artists from Mexico ...
# 100930  1840083521            Anime & Otaku Inspired Hard Enamel Pins
# 28719   2037414219                                    Phantasma Tarot
# 28718    702482592                            Lightsaber Dueling Club
# 28717   1752097539        Ligeti Lines Collaboration: Music-Art-Dance
# 28710   1261841426  Atomic Jukebox "Swami" Shirt by Stephen Blicke...
# 28708    345681431                                              TOAST
# 28703    186228525                                              Alice
# 28701   2124851535        Stix - A Marionette in Manhattan (Canceled)
# 100978  2133093685                         IDENTITY: The Sound in Art
# 28699   1096259266  Rude Moods: An Enamel Pin Collection of Mythic...
# 100979   615443593                      futuristic Armour Fabrication
# 28695   1429010779                                  Gobelins Handmade
# 28694   1123279493                 CARDBOARDs - A Commissions Project
# 28745   1332110823  Equality Through Understanding: Spreading the ...
# 28746   1831001833                   Oh Man: A Rick and Morty Fanzine
# 28747   1732904234                           The Above Ground Project
# 28748   2029693209                                          Flow Arts
# 28788    355308355                               SU Weapon Collection
# 169264  1392764387                                 NSF CRXSS PLATFXRM
# 169263   915828226                            Prints of beautiful art
# 169248   800617564        "Richer Than Gold" - The Fairy Tale Project
# ...            ...                                                ...
# 205502  1796509869      The Claymore Live Internet Sketch Comedy Show
# 205520  1569852938                                          Star Mage
# 205530   377507516           Tales Of The Brothers Three: Volume One!
# 205546   479369969                  Webcomic Underdogs: The Anthology
# 205548   182577275  The Realm - Mexican Ghost Story - My First Gra...
# 205555   770306562                               From Scratch Reprint
# 205561  1850822067  ~Archive: a Knowledge Tool by the Brooklyn Ins...
# 205564    49743357   RUNNER - An Action/Adventure Comic For Everyone!
# 205566  1040287573                               Today's Hero Issue 1
# 205567   553747814                                          Once Dead
# 205573   624644055  Akiba Anime Art Magazine vol.00 - Otaku pop  c...
# 205575  1888715467            Seeking Shelter: First Print Collection
# 205579  1479133032                                         The Get Up
# 205580  1739253624  Experience an Odyssey with the Aspen/National ...
# 205581  1066470702                       The Olympia Arts Perspective
# 205590  2064162560                                Delorean Hovercraft
# 205599  1403180543                  2 Smelly Kids That Like Eachother
# 205601  1527819477           Vortex Playing Cards by Alexander Isaacs
# 205603   532174385                         domekit.cc — domes for all
# 205620   971612340          The Princess Lucinda graphic novel series
# 205624    12804210  FIRST FTC Student Robot Construction - #2845 T...
# 205625   325920010          Facebeast: A Tale of a Bearded Super Hero
# 205636  1277165938      PANTHEON -The True Story of the Egyptian Gods
# 205645  1191600995            #9 Teen by ROBIN SNYDER AND STEVE DITKO
# 205648  1571759265                 Mini-Comic Residency in Pittsburgh
# 205654  1776728474                            Icarus: A Graphic Novel
# 205663  1830412546              Kickstand Comics: Volumes 2, 3, and 4
# 205673  2136296390                              kaBOOMbox: Volume One
# 205676   809522583                             Nowhere Man: Jacked Up
# 205687   243018882  Cartoon Block Sketches Vol. 1: The Art of Evan...
#
#                                                     blurb    category_name  \
# 178671  We would like to invite you to take part in br...  Performance Art
# 100894  Help fund the production of Lucky Daruma Doll ...     Illustration
# 28743   A 140 page full color 6"x 9" Hard Cover book c...     Illustration
# 100896  Soft enamel pins based on and inspired by clas...     Illustration
# 169239  A gold-plated enamel pin based on the hyper-co...      Mixed Media
# 100902  I am a junior in high school and my art class ...      Mixed Media
# 28734   The Summer Arts Camp will serve Navajo childre...  Performance Art
# 169238  I am in Puerto Rico (USA).  I have a project i...      Mixed Media
# 28730   Help us bring artists from Mexico to Arizona i...  Performance Art
# 100930  Anime and otaku related 1.5" hard enamel pins....      Mixed Media
# 28719   Phantasma is a tarot-inspired card deck influe...     Illustration
# 28718   A club oriented around (safely) learning how t...  Performance Art
# 28717   An exploration of the Ligeti Solo Sonata for C...  Performance Art
# 28710   Mystical Jerry Clayworth / Atomic Jukebox "Swa...     Illustration
# 28708   Live events centered around women. Poetry, mus...  Performance Art
# 28703   Who are you? Bedlam's Alice is about the divid...  Performance Art
# 28701   Stix the marionette entertains, delights, and ...  Performance Art
# 100978  A collaborative art show that transforms visua...      Mixed Media
# 28699   An Enamel Pin Collection of Mythical Beasts wi...     Illustration
# 100979  I'm trying to make a 2nd suit of armour I made...      Mixed Media
# 28695   Tapestry is a decorative textures of wool or s...  Performance Art
# 28694   CARDBOARDs - is a Commissions project, where y...     Illustration
# 28745               Everybody's story makes a difference.  Performance Art
# 28746   A fanzine dedicated to the animated show "Rick...     Illustration
# 28747   An amalgamation of art, tap dance, music, digi...  Performance Art
# 28748   A business designed to share our love of flows...  Performance Art
# 28788   Enamel pins based off weapons from Steven Univ...     Illustration
# 169264  NSF CRXSS PLATFXRM is a unique and multi-disci...      Mixed Media
# 169263  Trying to do prints of my artwork to get into ...      Mixed Media
# 169248  A mixed media art exhibit inspired by the magi...      Mixed Media
# ...                                                   ...              ...
# 205502  Claymore Productions is harnessing both the po...           Comics
# 205520  Darien Connors is the key in a war between mag...           Comics
# 205530  Brothers Three: Vol 1, will contain the advent...           Comics
# 205546  The eagerly-anticipated collection of art and ...           Comics
# 205548  The Realm is a dark and gritty, 80-page graphi...           Comics
# 205555  A group of supernatural creatures are hired to...           Comics
# 205561  It's not an archive. It's a tool. Help us deve...       Technology
# 205564  A Sci-Fi, Action/Comedy that can be enjoyed by...           Comics
# 205566  A twisted look at the world of super-heroes, g...           Comics
# 205567  Where will you go when you die? There are many...           Comics
# 205573  A brand new pop-culture magazine from Akihabar...           Comics
# 205575  A comic about hilarious and poignant true adve...           Comics
# 205579  An original sci-fi comic book entitled "The Ge...           Comics
# 205580  We want you to experience getting "inspired an...       Technology
# 205581  THE OLY ARTS PERSPECTIVE PRESENTS:\nVARIABLES:...              Art
# 205590  I'm building a hovercraft based on the bluepri...       Technology
# 205599  2 Smelly Kids has reached its first year, and ...           Comics
# 205601  The Vortex deck of playing cards is inspired b...              Art
# 205603  open-source, parametric software tools and sel...       Technology
# 205620  A different kind of graphic novel for a differ...           Comics
# 205624  You will be funding the construction of a FIRS...       Technology
# 205625  "I am the world's first pioneer of bearded jus...           Comics
# 205636  A graphic novel retelling of the Egyptian myth...           Comics
# 205645  ROBIN SNYDER AND STEVE DITKO\n\t    Celebrate ...           Comics
# 205648  A month in Pittsburgh refining my craft of wor...           Comics
# 205654  An original graphic novel from Gregory Wilson ...           Comics
# 205663  Preorder the second, third, and fourth collect...           Comics
# 205673  Brand New Nostalgia presents kaBOOMbox: Volume...           Comics
# 205676  Help fund the continuation of “Nowhere Man”, o...           Comics
# 205687  Finally here, a HARDCOVER book PACKED with ske...           Comics
#
#               category_slug  category_position  category_parent_id     goal  \
# 178671  art/performance art                  8                 1.0   3000.0
# 100894     art/illustration                  4                 1.0     80.0
# 28743      art/illustration                  4                 1.0  10000.0
# 100896     art/illustration                  4                 1.0    200.0
# 169239      art/mixed media                  6                 1.0    100.0
# 100902      art/mixed media                  6                 1.0   3300.0
# 28734   art/performance art                  8                 1.0   5000.0
# 169238      art/mixed media                  6                 1.0  25000.0
# 28730   art/performance art                  8                 1.0   3500.0
# 100930      art/mixed media                  6                 1.0    250.0
# 28719      art/illustration                  4                 1.0    350.0
# 28718   art/performance art                  8                 1.0    350.0
# 28717   art/performance art                  8                 1.0   5000.0
# 28710      art/illustration                  4                 1.0    100.0
# 28708   art/performance art                  8                 1.0   5000.0
# 28703   art/performance art                  8                 1.0   2000.0
# 28701   art/performance art                  8                 1.0   5000.0
# 100978      art/mixed media                  6                 1.0   6500.0
# 28699      art/illustration                  4                 1.0    650.0
# 100979      art/mixed media                  6                 1.0    150.0
# 28695   art/performance art                  8                 1.0   5000.0
# 28694      art/illustration                  4                 1.0    300.0
# 28745   art/performance art                  8                 1.0   2000.0
# 28746      art/illustration                  4                 1.0   4900.0
# 28747   art/performance art                  8                 1.0  10000.0
# 28748   art/performance art                  8                 1.0   5000.0
# 28788      art/illustration                  4                 1.0    180.0
# 169264      art/mixed media                  6                 1.0   2500.0
# 169263      art/mixed media                  6                 1.0    500.0
# 169248      art/mixed media                  6                 1.0   5800.0
# ...                     ...                ...                 ...      ...
# 205502               comics                  2                 NaN   5000.0
# 205520               comics                  2                 NaN   2500.0
# 205530               comics                  2                 NaN   3000.0
# 205546               comics                  2                 NaN   2500.0
# 205548               comics                  2                 NaN   5000.0
# 205555               comics                  2                 NaN   3000.0
# 205561           technology                 14                 NaN   7500.0
# 205564               comics                  2                 NaN   6000.0
# 205566               comics                  2                 NaN   1500.0
# 205567               comics                  2                 NaN    700.0
# 205573               comics                  2                 NaN   4500.0
# 205575               comics                  2                 NaN     50.0
# 205579               comics                  2                 NaN   2400.0
# 205580           technology                 14                 NaN   2000.0
# 205581                  art                  1                 NaN   3000.0
# 205590           technology                 14                 NaN   5500.0
# 205599               comics                  2                 NaN    500.0
# 205601                  art                  1                 NaN  20000.0
# 205603           technology                 14                 NaN   5000.0
# 205620               comics                  2                 NaN   4000.0
# 205624           technology                 14                 NaN   1000.0
# 205625               comics                  2                 NaN   1000.0
# 205636               comics                  2                 NaN   8000.0
# 205645               comics                  2                 NaN   2100.0
# 205648               comics                  2                 NaN    200.0
# 205654               comics                  2                 NaN   8000.0
# 205663               comics                  2                 NaN  18000.0
# 205673               comics                  2                 NaN   9500.0
# 205676               comics                  2                 NaN   2000.0
# 205687               comics                  2                 NaN   9500.0
#
#          pledged  disable_communication loc_country         loc_state country  \
# 178671    106.00                  False          US                MI      US
# 100894     87.00                  False          US                MA      US
# 28743   10916.00                  False          US                CA      US
# 100896    310.00                  False          US                IL      US
# 169239    508.29                  False          CA                ON      CA
# 100902   3300.00                  False          US                CA      US
# 28734    1971.00                  False          US                NM      US
# 169238      7.00                  False          PR        Río Grande      US
# 28730    3800.00                  False          US                AZ      US
# 100930   1982.00                  False          US                TX      US
# 28719    2090.00                  False          US                IN      US
# 28718     121.00                  False          US                NC      US
# 28717    5050.00                  False          GB           England      US
# 28710     260.00                  False          US                TX      US
# 28708     235.00                  False          US                CA      US
# 28703    2405.00                  False          US                NY      US
# 28701     176.50                  False          US                NY      US
# 100978    344.00                  False          US                NV      US
# 28699    8615.00                  False          US                AZ      US
# 100979     11.00                  False          GB           England      GB
# 28695       5.00                  False          GB           England      GB
# 28694    1091.00                  False          US                UT      US
# 28745    3925.00                  False          US                MN      US
# 28746    7191.85                  False          US                TN      US
# 28747      10.00                  False          US                NJ      US
# 28748      61.00                  False          US                LA      US
# 28788     996.00                  False          US                TX      US
# 169264   2508.00                  False          GB           England      GB
# 169263    700.00                  False          US                MO      US
# 169248   6071.00                  False          US                MI      US
# ...          ...                    ...         ...               ...     ...
# 205502   6075.02                  False          US                IL      US
# 205520   5250.00                  False          US                FL      US
# 205530   3160.00                  False          US                CA      US
# 205546   3175.00                  False          US                WA      US
# 205548   5513.00                  False          US                CA      US
# 205555   3320.73                  False          US                OR      US
# 205561   9211.00                  False          US                NY      US
# 205564   6619.00                  False          US                CA      US
# 205566   1683.01                  False          US                NY      US
# 205567   1095.00                  False          US                PA      US
# 205573  74003.28                  False          JP  Tokyo Prefecture      US
# 205575   1104.00                  False          US                MA      US
# 205579   2512.00                  False          US                CA      US
# 205580   2275.00                  False         NaN               NaN      US
# 205581   3000.00                  False          US                WA      US
# 205590   5644.38                  False          US                CA      US
# 205599    515.00                  False          US                MO      US
# 205601  32017.21                  False          US                NV      US
# 205603   5366.00                  False          US                NY      US
# 205620   7166.13                  False          US                TX      US
# 205624   1553.00                  False          US                FL      US
# 205625   5299.00                  False          US                FL      US
# 205636  10405.01                  False          GB           England      GB
# 205645   5045.00                  False          US                WA      US
# 205648    867.00                  False          US                PA      US
# 205654  15884.49                  False          US                DC      US
# 205663  44054.00                  False          US                OH      US
# 205673  14458.00                  False          US                MA      US
# 205676   3174.00                  False          US                NY      US
# 205687  25128.00                  False          US                CA      US
#
#        currency  currency_trailing_code    deadline  state_changed_at  \
# 178671      USD                    True  1427932800        1427932817
# 100894      USD                    True  1443412740        1443412741
# 28743       USD                    True  1504710097        1504710098
# 100896      USD                    True  1509645600        1509645601
# 169239      CAD                    True  1538006856        1538006857
# 100902      USD                    True  1423367143        1423367143
# 28734       USD                    True  1373061600        1373061637
# 169238      USD                    True  1425064860        1425064861
# 28730       USD                    True  1303282740        1303282741
# 100930      USD                    True  1510386238        1510386238
# 28719       USD                    True  1479132548        1479132548
# 28718       USD                    True  1388344155        1388344156
# 28717       USD                    True  1441642734        1441642734
# 28710       USD                    True  1383350400        1383350416
# 28708       USD                    True  1466028586        1466028586
# 28703       USD                    True  1333242720        1333242720
# 28701       USD                    True  1384229460        1384208163
# 100978      USD                    True  1338239460        1338239460
# 28699       USD                    True  1541012400        1538377202
# 100979      GBP                   False  1418257292        1418257294
# 28695       GBP                   False  1435651920        1435651921
# 28694       USD                    True  1512147627        1512147628
# 28745       USD                    True  1404895303        1404895303
# 28746       USD                    True  1455125403        1455125403
# 28747       USD                    True  1407167947        1407167949
# 28748       USD                    True  1477187333        1477187333
# 28788       USD                    True  1537960049        1537960050
# 169264      GBP                   False  1534328251        1534328251
# 169263      USD                    True  1342983233        1342983233
# 169248      USD                    True  1362664811        1362664836
# ...         ...                     ...         ...               ...
# 205502      USD                    True  1266991140        1266991211
# 205520      USD                    True  1374144112        1374144112
# 205530      USD                    True  1345460520        1345460520
# 205546      USD                    True  1388822340        1388822340
# 205548      USD                    True  1352012340        1352012341
# 205555      USD                    True  1365795997        1365795997
# 205561      USD                    True  1337176811        1337176818
# 205564      USD                    True  1394384799        1394384801
# 205566      USD                    True  1364615940        1364615942
# 205567      USD                    True  1318473267        1318473267
# 205573      USD                    True  1381712400        1381712416
# 205575      USD                    True  1394929705        1394929706
# 205579      USD                    True  1330633640        1330633642
# 205580      USD                    True  1280440800        1280440809
# 205581      USD                    True  1301702400        1301702420
# 205590      USD                    True  1279609140        1279609212
# 205599      USD                    True  1316801629        1316801629
# 205601      USD                    True  1322899140        1322899140
# 205603      USD                    True  1309554000        1309554024
# 205620      USD                    True  1341516968        1341516968
# 205624      USD                    True  1372467233        1372467233
# 205625      USD                    True  1360544400        1360544433
# 205636      GBP                   False  1391987064        1391987064
# 205645      USD                    True  1396198057        1396198058
# 205648      USD                    True  1354143000        1354143000
# 205654      USD                    True  1392267540        1392267541
# 205663      USD                    True  1323977020        1323977021
# 205673      USD                    True  1351051410        1351051412
# 205676      USD                    True  1402140268        1402140270
# 205687      USD                    True  1373723537        1373723537
#
#         created_at  launched_at  staff_pick  backers_count  spotlight  \
# 178671  1407959494   1423095673       False              4      False
# 100894  1440999408   1441175615       False              6       True
# 28743   1418658363   1502118097       False            148       True
# 100896  1506140033   1506958368       False             18       True
# 169239  1530900104   1535414856       False             31       True
# 100902  1417586411   1420775143       False             22       True
# 28734   1367258299   1370384587       False             39      False
# 169238  1422472858   1422713654       False              3      False
# 28730   1297728976   1297928928       False            102       True
# 100930  1507142888   1507790638       False             79       True
# 28719   1476317037   1476450548       False             40       True
# 28718   1384610857   1385752155       False              5      False
# 28717   1438937269   1439050734       False             35       True
# 28710   1381683194   1381862742       False             11       True
# 28708   1461566342   1463436586       False              7      False
# 28703   1330986191   1331324084       False             49       True
# 28701   1380858431   1381646759       False             10      False
# 100978  1335398864   1335812301        True             18      False
# 28699   1534400703   1538377202       False            137      False
# 100979  1415365341   1415665292       False              2      False
# 28695   1428391436   1432658713       False              1      False
# 28694   1508864980   1509552027       False             23       True
# 28745   1360613707   1402735303       False             55       True
# 28746   1452390058   1452533403       False            282       True
# 28747   1405173134   1405439947       False              2      False
# 28748   1474586596   1474595333       False              3      False
# 28788   1535159462   1535368049       False             29       True
# 169264  1528733194   1531736251       False             26       True
# 169263  1339032381   1340391233       False             26       True
# 169248  1358252037   1360072811       False             70       True
# ...            ...          ...         ...            ...        ...
# 205502  1260825581   1262032817       False             94       True
# 205520  1371260360   1371552112       False            235       True
# 205530  1340136137   1340324068       False             56       True
# 205546  1385513955   1385953159       False             86       True
# 205548  1349201207   1349821312       False             98       True
# 205555  1362077600   1363203997       False            112       True
# 205561  1333060058   1333288811        True            204       True
# 205564  1391142400   1391796399       False             93       True
# 205566  1358743719   1360242942       False             52       True
# 205567  1315803036   1315881267        True             36       True
# 205573  1374052000   1377276934       False           1548       True
# 205575  1386605659   1392514105       False             32       True
# 205579  1328029895   1328041640       False             54       True
# 205580  1278551674   1278559119       False             23       True
# 205581  1298930962   1298935511       False             44       True
# 205590  1275429825   1275891002        True            150       True
# 205599  1314037481   1314209629       False             13       True
# 205601  1314983600   1318218149       False            585       True
# 205603  1306869495   1307061046        True             80       True
# 205620  1338480036   1338924968       False            190       True
# 205624  1367088853   1369875233       False             28       True
# 205625  1356367440   1357140086        True            224       True
# 205636  1386923191   1389395064        True            368       True
# 205645  1393551758   1393609657       False            202       True
# 205648  1349992252   1350563865        True             44       True
# 205654  1389308024   1389675907       False            401       True
# 205663  1305316277   1318789420        True            660       True
# 205673  1347163273   1348459410        True            298       True
# 205676  1397785619   1399548268       False             55       True
# 205687  1368509355   1371131537        True            594       True
#
#         creator_registered       state
# 178671                True      failed
# 100894                True  successful
# 28743                 True  successful
# 100896                True  successful
# 169239                True  successful
# 100902                True  successful
# 28734                 True      failed
# 169238                True      failed
# 28730                 True  successful
# 100930                True  successful
# 28719                 True  successful
# 28718                 True      failed
# 28717                 True  successful
# 28710                 True  successful
# 28708                 True      failed
# 28703                 True  successful
# 28701                 True    canceled
# 100978                True      failed
# 28699                 True        live
# 100979                True      failed
# 28695                 True      failed
# 28694                 True  successful
# 28745                 True  successful
# 28746                 True  successful
# 28747                 True      failed
# 28748                 True      failed
# 28788                 True  successful
# 169264                True  successful
# 169263                True  successful
# 169248                True  successful
# ...                    ...         ...
# 205502                True  successful
# 205520                True  successful
# 205530                True  successful
# 205546                True  successful
# 205548                True  successful
# 205555                True  successful
# 205561                True  successful
# 205564                True  successful
# 205566                True  successful
# 205567                True  successful
# 205573                True  successful
# 205575                True  successful
# 205579                True  successful
# 205580                True  successful
# 205581                True  successful
# 205590                True  successful
# 205599                True  successful
# 205601                True  successful
# 205603                True  successful
# 205620                True  successful
# 205624                True  successful
# 205625                True  successful
# 205636                True  successful
# 205645                True  successful
# 205648                True  successful
# 205654                True  successful
# 205663                True  successful
# 205673                True  successful
# 205676                True  successful
# 205687                True  successful
#
# [187074 rows x 24 columns]

# %% [markdown]
# # variable notes
#
# ## delete
# * blurb - delete
# * loc_state - delete (too granular)
# * country - delete (not sure how it differs from loc_country; largely redundant)
# * currency - delete (pledges is in usd)
# * currency_trailing_code - delete (what is it?)
# * state_changed_at - delete
#
# ## keep
# * id - keep (primary key)
# * name - keep (for reference)
# * category_name - keep; change to sub_category
# * category slug - keep; extract first word; change to category
# * category_position - keep; change to sub_category_id; move before sub_category
# * category_parent_id - keep; change to category_id; move before category_name
# * goal - keep
# * pledged - keep
# * disable_communication - keep (but what is it??)
# * loc_country - keep (where the project is launche from); rename as country
# * deadline - keep; convert to datetime
# * created_at - keep; convert to datetime
# * launched_at - keep; convert to datetime
# * staff_pick - keep
# * backers_count - keep; move before pledged
# * spotlight - keep (but what is it?)
# * creator_registered - keep
# * state - keep

# %%
len(df.category_name.unique())
# Out:
# 159

# %%
len(df.category_slug.unique())
# Out:
# 169

# %%
len(df.category_position.unique())
# Out:
# 19

# %%
df.category_position.unique()
# Out:
# array([15,  7,  5, 10, 12,  2,  1,  8,  3, 14,  6,  4, 11, 13,  9, 16, 17,
#        19, 18], dtype=int64)

# %%
len(df.category_parent_id.unique())
# Out:
# 16

# %%
df.category_parent_id.unique()
# Out:
# array([16., 12., 18.,  9.,  1., nan,  3., 11., 13., 15., 17.,  6., 14.,
#        26., 10.,  7.])

# %% [markdown]
# # Stopped here

# %%
# ---- Drop columns ----
to_drop = [
    "Edition Statement",
    "Corporate Author",
    "Corporate Contributors",
    "Former owner",
    "Engraver",
    "Contributors",
    "Issuance type",
    "Shelfmarks"]

df.drop(columns=to_drop, inplace=True)

# %%
df.head()

# %%
# ---- Change index ----
df["Identifier"].is_unique

# %%
df.set_index("Identifier", inplace=True)
df.head(10)

# %%
# ---- Clean specific columns ----
df.get_dtype_counts()

# %%
# ---- Dates ----
  # Extract first 4-digit numbers to be the year
  # This removes any punctuations, converts data ranges to start dates, and changes any non-conforming cells to NaN
extr = df["Date of Publication"].str.extract(r'^(\d{4})', expand=False)
df["Date of Publication"] = pd.to_numeric(extr)
df["Date of Publication"]

# %%
print(f"{round(df['Date of Publication'].isnull().sum() / len(df) * 100,1)}% of the data is null.")

# %%
# ---- Locations ----
  # Use np.where(condition, then, else)
df["Place of Publication"].head(10)

# %%
pub.nunique()

# %%
pub.unique()

# %%
pub = df["Place of Publication"]
london = pub.str.contains("London")
london[:10]

# %%
oxford = pub.str.contains("Oxford")
oxford[:10]

# %%
# Fix "London", "Oxford", and entries with "-"
df["Place of Publication"] = np.where(london, "London",
    np.where(oxford, "Oxford",
    pub.str.replace("-", " ")))
df["Place of Publication"].head(10)

# %%
df["Place of Publication"].nunique()

# %%
# ... Repeat for all data
df["Place of Publication"].unique()

# %%
coventry = pub.str.contains("Coventry")
merida_de_yucatan = pub.str.contains("Merida de Yucatan")
moscow = pub.str.contains("Moscow|Москва|Moskwa")

df["Place of Publication"] = np.where(coventry, "Coventry",
    np.where(merida_de_yucatan, "Merida de Yucatan",
    np.where(moscow, "Moscow",df["Place of Publication"])))

print(f"Number of unique entries: {df['Place of Publication'].nunique()}")
print(f"Unique entries: {df['Place of Publication'].unique()}")

# %%
paris = pub.str.contains("Paris")
lyon = pub.str.contains("Lyon")
moscow = pub.str.contains("Москвѣ")

df["Place of Publication"] = np.where(paris, "Paris",
    np.where(lyon, "Lyon",
    np.where(moscow, "Moscow", df["Place of Publication"])))

print(f"Number of unique entries: {df['Place of Publication'].nunique()}")
print(f"Unique entries: {df['Place of Publication'].unique()}")

# %%
nottingham = pub.str.contains("Nottingham")
viena = pub.str.contains("Viena")

df["Place of Publication"] = np.where(nottingham, "Nottingham",
    np.where(viena, "Viena", df["Place of Publication"]))

print(f"Number of unique entries: {df['Place of Publication'].nunique()}")
print(f"Unique entries: {df['Place of Publication'].unique()}")

# %%
df.groupby(["Place of Publication"]).describe()

# %%
# ---- Convert locations column to categorical ----
"""
place = pd.get_dummies(df["Place of Publication"],drop_first=True)
df.drop(["Place of Publication"],axis=1,inplace=True)
df = pd.concat([df,place],axis=1)
df.head(10)
"""

# %%
# ---- Clean entire dataset using applymap ----
# !more Datasets\\university_towns.txt

# %%
university_towns = []
with open("Datasets/university_towns.txt") as file:
    for line in file:
        if "[edit]" in line:
            # Remember this state until the next is found
            state = line
        else:
            # Otherwise we have a city - keep the state
            university_towns.append((state, line))
        
university_towns

# %%
towns_df = pd.DataFrame(university_towns, columns=["State", "RegionName"])
towns_df

# %%
# Function: Grab state and city data
def get_citystate(item):
    if " (" in item:
        return item[:item.find(" (")]
    elif "[" in item:
        return item[:item.find("[")]
    else:
        return item

# %%
# applymap the function
towns_df = towns_df.applymap(get_citystate)
towns_df

# %%
# ---- Organize column labels ----
olympics_df = pd.read_csv("Datasets/olympics.csv")
olympics_df

# %%
# Skip the top row and set the header
olympics_df = pd.read_csv("Datasets/olympics.csv", header=1)
olympics_df

# %%
# Rename the columns
olympics_df.columns

# %%
new_names = {'Unnamed: 0': 'Country',
            '? Summer': 'Summer Olympics',
            '01 !': 'Gold',
            '02 !': 'Silver',
            '03 !': 'Bronze',
            '? Winter': 'Winter Olympics',
            '01 !.1': 'Gold.1',
            '02 !.1': 'Silver.1',
            '03 !.1': 'Bronze.1',
            '? Games': '# Games',
            '01 !.2': 'Gold.2',
            '02 !.2': 'Silver.2',
            '03 !.2': 'Bronze.2'}

# %%
olympics_df.rename(columns=new_names, inplace=True)
olympics_df
